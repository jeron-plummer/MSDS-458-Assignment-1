# %% [markdown]
# <img src="https://github.com/KartikNW/MSDS_458_Public/blob/main/images2/NorthwesternHeader.png?raw=1" />

# %%
NOTEBOOK_VERSION = "1.0"
QUARTER = "Summer 2026"

from datetime import datetime
NOTEBOOK_START_TIME = datetime.now()
print(f"Notebook Version: {NOTEBOOK_VERSION} | {QUARTER}")
# Out:
# Notebook Version: 1.0 | Summer 2026

# %% [markdown]
# # Assignment 3 — Part C: Fine-tuning Pretrained Models for Text-to-Code Generation
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will:
#
# - Understand how to **fine-tune** a pretrained model for a specific task
# - Configure training hyperparameters for fine-tuning (vs training from scratch)
# - Train CodeT5 on MBPP dataset
# - Compare **three approaches**: From-scratch → Zero-shot → Fine-tuned
# - Understand the complete production pipeline for code generation
# - Measure improvement using BLEU scores and syntax validity
#
# ## 📊 Three-Way Comparison Framework
#
# This notebook demonstrates the **industry-standard approach** by comparing:
#
# **Part A (From Scratch):**
# - Transformer from scratch (2 layers, 256 dim, ~1M parameters)
# - Random initialization, trained on 374 examples
# - **BLEU**: 0.77, **Syntax Valid**: 0%
# - ❌ Not production-ready
#
# **Part B (Pretrained - Zero-Shot):**
# - CodeT5+ 220M Python (220M parameters, pretrained + Python-tuned)
# - No task-specific training
# - **BLEU**: See Part B results, **Syntax Valid**: See Part B results
# - ⚠️ Better than from-scratch but limited
#
# **Part C (Fine-Tuned) - THIS NOTEBOOK:**
# - Same CodeT5+ model, fine-tuned on 374 MBPP examples
# - Only 5 epochs needed
# - **BLEU**: Expected 40-60, **Syntax Valid**: Expected 90%+
# - ✅ Production-ready approach
#
# ## ⚠️ Prerequisites
#
# **You should complete Part B first!**
# - Part B establishes the zero-shot baseline we'll compare against
# - This notebook references Part B's zero-shot BLEU scores
# - If you haven't run Part B yet, do that first

# %% [markdown]
# ## Notebook Overview
#
# - 🧩 Step 1: Setup and Imports
# - 📦 Step 1B: Import Shared Utilities
# - 🗂️ Step 2: Load and Process MBPP Dataset
# - 🤖 Step 4: Load Pretrained CodeT5+ Model
# - 🔧 Step 5: Prepare Data for Fine-tuning
# - 🚀 Step 6: Fine-tune CodeT5
# - 🔬 Step 6B: Weight Change Analysis
# - 🔍 Step 7: Evaluate Fine-Tuned Model
# - 📊 Step 7B: BLEU Evaluation of Fine-Tuned CodeT5+
# - 📊 Step 8: Three-Way Model Comparison
# - 🎓 Key Insights from Three-Way Comparison
# - 📊 Final Summary: What You Learned
# - 📝 Assignment 3 Complete!

# %% [markdown]
# ## 🧩 Step 1: Setup and Imports
#
# In this step, you will import all necessary libraries:
#
# - **Transformers** - Hugging Face library for pretrained models (CodeT5)
# - **Datasets** - For loading MBPP
# - **TensorFlow/Keras** - Backend for CodeT5 model
# - **Evaluation metrics** - To measure code generation quality

# %%
# Install required packages (run this in Colab or local environment)
# Note: tf-keras is required because Transformers doesn't yet support Keras 3
# Note: torch is required for loading CodeT5 weights from PyTorch
# Uncomment the line below if running on Colab or if packages are not installed
# !pip3 install -q "transformers>=4.47.0,<5.0" datasets tf-keras evaluate torch

print("✅ Packages already installed via uv!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 90.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 38.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.20.0 requires huggingface-hub<2.0,>=1.2.0, but you have huggingface-hub 0.36.2 which is incompatible.
# ✅ Packages already installed via uv!

# %%
# Core dependencies
import tensorflow as tf
# Disable Metal GPU locally — T5 beam search uses XLA ops unsupported by Metal plugin
# (Colab uses CUDA which supports these ops fine)
import sys
if sys.platform == 'darwin':
    tf.config.set_visible_devices([], 'GPU')
import tf_keras as keras  # Use tf-keras (Keras 2) instead of Keras 3
from transformers import (
    TFAutoModelForSeq2SeqLM,
    AutoTokenizer,
)
from datasets import load_dataset
import numpy as np
import pandas as pd
import evaluate
import os
import random
from tqdm import tqdm
import matplotlib.pyplot as plt

# For reproducibility
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print(f"✅ Libraries imported successfully!")
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# ✅ Libraries imported successfully!
# TensorFlow version: 2.20.0
# Keras version: 2.20.0

# %% [markdown]
# ## 📦 Step 1B: Import Shared Utilities
#
# This cell automatically downloads `assignment3_utils.py` if running in Google Colab or if the file is missing locally.
#
# The utilities module provides:
# - **Configuration**: MBPP dataset loading and processing
# - **Data Loading**: Functions to load and extract dataset examples
# - **Data Processing**: Functions to prepare training data
# - **BLEU Evaluation**: Functions to evaluate model performance
#
# **Note**: This works seamlessly in both local Jupyter and Google Colab environments.

# %%
import os, sys, urllib.request

IN_COLAB = 'google.colab' in sys.modules
UTILS_BRANCH = "main"

def fetch_github_raw(user, repo, branch, file_path, local_path):
    url = f"https://raw.githubusercontent.com/{user}/{repo}/{branch}/{file_path}"
    urllib.request.urlretrieve(url, local_path)
    print(f"Fetched {file_path} from branch '{branch}'.")

if IN_COLAB:
    if not os.path.exists("assignment3_utils.py"):
        fetch_github_raw("KartikNW", "MSDS_458_Public", UTILS_BRANCH,
            "MSDS458_Assignment_03/assignment3_utils.py", "assignment3_utils.py")
else:
    print("Using local assignment3_utils.py")

# Import utilities (Note: DATASET is defined in this notebook, not imported)
from assignment3_utils import (
    # Data loading & processing
    prepare_training_data,
    # BLEU evaluation
    add_python_hint,
    compute_bleu_for_code,
    evaluate_model_with_bleu,
    analyze_bleu_results,
    # Batch generation
    batch_generate_codes,
)

print("✅ Utilities imported successfully")
# Out:
# Fetched MSDS458_Assignment_03/assignment3_utils.py from branch 'main'.
# ✅ assignment3_utils v1.0.1 loaded successfully
# ✅ Utilities imported successfully

# %% [markdown]
# ## 🗂️ Step 2: Load and Process MBPP Dataset
#
# In this step, you will:
#
# - Load MBPP (Mostly Basic Python Problems) dataset
# - Extract problem descriptions and Python solutions
# - Process data into train/validation/test splits
#
# MBPP contains 974 Python programming problems:
# - **Train**: 374 examples
# - **Validation**: 90 examples
# - **Test**: 50 examples

# %%
# ========================================
# LOAD AND PROCESS MBPP DATASET
# ========================================

print("Loading and processing MBPP dataset...")
print("This uses shared utilities from assignment3_utils.py")
print("=" * 60)

# Load and process all splits using shared utility
data = prepare_training_data("MBPP")

# Extract data into variables (maintaining compatibility with rest of notebook)
train_prompts = data['train']['prompts']
train_code = data['train']['code']

val_prompts = data['val']['prompts']
val_code = data['val']['code']

test_prompts = data['test']['prompts']
test_code = data['test']['code']

print("=" * 60)
print(f"📊 Dataset sizes:")
print(f"  Train: {len(train_prompts)}")
print(f"  Val: {len(val_prompts)}")
print(f"  Test: {len(test_prompts)}")
print("✅ Dataset loaded and processed successfully!")
# Out:
# Loading and processing MBPP dataset...
# This uses shared utilities from assignment3_utils.py
# ============================================================
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# full/train-00000-of-00001.parquet:   0%|          | 0.00/87.2k [00:00<?, ?B/s]
# full/test-00000-of-00001.parquet:   0%|          | 0.00/116k [00:00<?, ?B/s]
# full/validation-00000-of-00001.parquet:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# full/prompt-00000-of-00001.parquet:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/374 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/90 [00:00<?, ? examples/s]
# Generating prompt split:   0%|          | 0/10 [00:00<?, ? examples/s]
# Processing MBPP dataset...
#   Train: 374 examples
#   Val: 90 examples
#   Test: 50 examples
# ============================================================
# 📊 Dataset sizes:
#   Train: 374
#   Val: 90
#   Test: 50
# ✅ Dataset loaded and processed successfully!

# %% [markdown]
# ## 🤖 Step 4: Load Pretrained CodeT5+ Model
#
# In this step, you will:
#
# - Load **CodeT5+ 220M Python** - a 220M parameter model pretrained on code
# - Load the corresponding tokenizer
# - Understand the model architecture
#
# **CodeT5+ (Python variant)** was trained on:
# - Large-scale code corpus with improved pretraining objectives
# - Multiple programming languages, then fine-tuned on Python
# - Advanced tasks: span denoising, causal LM, contrastive learning, text-code matching
#
# This gives it a strong foundation for Python code generation!
#
# **Note**: We start from the same pretrained model as Part B, but we'll fine-tune it in this notebook.

# %%
# ========================================
# LOAD CODET5 MODEL AND TOKENIZER
# ========================================

MODEL_NAME = "Salesforce/codet5p-220m-py"  # --- EXPERIMENT HERE: try other models (codet5-base, codet5p-770m, etc.) ---

print(f"Loading pretrained model: {MODEL_NAME}")
print("Note: CodeT5+ is an improved version of CodeT5 with better pretraining")
print("This may take a few minutes on first run (downloads ~250MB)...")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Load pretrained model
# Try loading TensorFlow weights directly first (no PyTorch conversion needed)
try:
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
    print("✅ Loaded from TensorFlow weights")
except Exception as e:
    print(f"TensorFlow weights not available, trying PyTorch conversion...")
    print(f"Note: This requires PyTorch to be installed")
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME, from_pt=True)

print(f"\n✅ Model and tokenizer loaded!")
print(f"Model type: {type(model).__name__}")
print(f"Tokenizer vocab size: {tokenizer.vocab_size:,}")
print(f"Model parameters: ~220M")
# Out:
# Loading pretrained model: Salesforce/codet5p-220m-py
# Note: CodeT5+ is an improved version of CodeT5 with better pretraining
# This may take a few minutes on first run (downloads ~250MB)...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# TensorFlow weights not available, trying PyTorch conversion...
# Note: This requires PyTorch to be installed
# pytorch_model.bin:   0%|          | 0.00/446M [00:00<?, ?B/s]
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFT5ForConditionalGeneration: ['lm_head.weight', 'decoder.embed_tokens.weight', 'encoder.embed_tokens.weight']
# - This IS expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ✅ Model and tokenizer loaded!
# Model type: TFT5ForConditionalGeneration
# Tokenizer vocab size: 32,100
# Model parameters: ~220M

# %%
# ========================================
# TEST TOKENIZER ON SAMPLE
# ========================================

# Get a sample from training data
sample_prompt = train_prompts[0]
sample_code = train_code[0]

print("Sample prompt:")
print(sample_prompt[:150] + "...")
print("\nSample code:")
print(sample_code[:150] + "...")

# Tokenize
inputs = tokenizer(sample_prompt, return_tensors="tf", truncation=True, max_length=128)
targets = tokenizer(sample_code, return_tensors="tf", truncation=True, max_length=256)

print(f"\nTokenized input shape: {inputs['input_ids'].shape}")
print(f"Tokenized target shape: {targets['input_ids'].shape}")
print(f"\nFirst 20 input tokens: {inputs['input_ids'][0, :20].numpy()}")
print(f"Decoded back: {tokenizer.decode(inputs['input_ids'][0, :20], skip_special_tokens=False)}")
# Out:
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Sample prompt:
# Write a function to find the longest chain which can be formed from the given set of pairs....
#
# Sample code:
# class Pair(object):
# 	def __init__(self, a, b):
# 		self.a = a
# 		self.b = b
# def max_chain_length(arr, n):
# 	max = 0
# 	mcl = [1 for i in range(n)...
#
# Tokenized input shape: (1, 21)
# Tokenized target shape: (1, 191)
#
# First 20 input tokens: [    1  3067   279   445   358  1104   326 12163  2687  1492   848   506
#  20010   628   326   864   444   434  5574    18]
# Decoded back: <s>Write a function to find the longest chain which can be formed from the given set of pairs.

# %% [markdown]
# ## 🔧 Step 5: Prepare Data for Fine-tuning
#
# In this step, you will prepare the dataset for fine-tuning:
#
# - Tokenize all training, validation, and test examples
# - Create TensorFlow datasets with proper batching
# - Set up the data pipeline for training
#
# **Key concepts:**
# - **Input IDs**: Tokenized problem descriptions (prompts)
# - **Labels**: Tokenized code solutions (what the model should generate)
# - **Attention masks**: Tell the model which tokens are real vs padding
# - **Batching**: Group examples together for efficient training

# %%
# ========================================
# TOKENIZATION CONFIGURATION
# ========================================

# Sequence length limits
# --- EXPERIMENT HERE: sequence lengths and batch size ---
MAX_INPUT_LENGTH = 128   # Maximum length for problem descriptions
MAX_TARGET_LENGTH = 256  # Maximum length for code solutions
BATCH_SIZE = 8           # Number of examples per batch (small due to model size)

print(f"Tokenization configuration:")
print(f"  Max input length: {MAX_INPUT_LENGTH}")
print(f"  Max target length: {MAX_TARGET_LENGTH}")
print(f"  Batch size: {BATCH_SIZE}")
# Out:
# Tokenization configuration:
#   Max input length: 128
#   Max target length: 256
#   Batch size: 8

# %%
# ========================================
# TOKENIZE DATASETS
# ========================================

def tokenize_function(prompts, codes):
    """
    Tokenize prompts and codes for seq2seq training.

    Args:
        prompts: List of problem descriptions
        codes: List of code solutions

    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    # Tokenize inputs (prompts)
    model_inputs = tokenizer(
        prompts,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Tokenize targets (codes)
    # Use text_target for encoder-decoder models
    labels = tokenizer(
        codes,
        max_length=MAX_TARGET_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Replace padding token id's in labels with -100 so they're ignored in loss
    labels_ids = labels['input_ids']
    labels_ids[labels_ids == tokenizer.pad_token_id] = -100

    return {
        'input_ids': model_inputs['input_ids'],
        'attention_mask': model_inputs['attention_mask'],
        'labels': labels_ids
    }

print("✅ Tokenization function defined")
# Out:
# ✅ Tokenization function defined

# %%
# ========================================
# TOKENIZE ALL DATA AND CREATE TF DATASETS
# ========================================

print("🔄 Tokenizing all datasets...")
print("=" * 60)

# Tokenize all three splits
train_dataset = tokenize_function(train_prompts, train_code)
print(f"✅ Training data tokenized ({len(train_prompts)} examples)")
print(f"   Input shape: {train_dataset['input_ids'].shape}")
print(f"   Labels shape: {train_dataset['labels'].shape}")

val_dataset = tokenize_function(val_prompts, val_code)
print(f"✅ Validation data tokenized ({len(val_prompts)} examples)")
print(f"   Input shape: {val_dataset['input_ids'].shape}")
print(f"   Labels shape: {val_dataset['labels'].shape}")

test_dataset = tokenize_function(test_prompts, test_code)
print(f"✅ Test data tokenized ({len(test_prompts)} examples)")
print(f"   Input shape: {test_dataset['input_ids'].shape}")
print(f"   Labels shape: {test_dataset['labels'].shape}")

print("\n" + "=" * 60)
print("🔄 Creating TensorFlow datasets for training...")

# Convert to TensorFlow datasets
# IMPORTANT: For seq2seq models, labels must be in the input dictionary
train_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': train_dataset['input_ids'],
    'attention_mask': train_dataset['attention_mask'],
    'labels': train_dataset['labels']
})

val_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': val_dataset['input_ids'],
    'attention_mask': val_dataset['attention_mask'],
    'labels': val_dataset['labels']
})

# Batch and shuffle
train_tf_dataset = train_tf_dataset.shuffle(1000).batch(BATCH_SIZE)
val_tf_dataset = val_tf_dataset.batch(BATCH_SIZE)

print(f"✅ TensorFlow datasets created")
print(f"  Training batches: {len(train_tf_dataset)}")
print(f"  Validation batches: {len(val_tf_dataset)}")
print("=" * 60)
# Out:
# 🔄 Tokenizing all datasets...
# ============================================================
# ✅ Training data tokenized (374 examples)
#    Input shape: (374, 128)
#    Labels shape: (374, 256)
# ✅ Validation data tokenized (90 examples)
#    Input shape: (90, 128)
#    Labels shape: (90, 256)
# ✅ Test data tokenized (50 examples)
#    Input shape: (50, 128)
#    Labels shape: (50, 256)
#
# ============================================================
# 🔄 Creating TensorFlow datasets for training...
# ✅ TensorFlow datasets created
#   Training batches: 47
#   Validation batches: 12
# ============================================================

# %% [markdown]
# ## 🚀 Step 6: Fine-tune CodeT5
#
# In this step, you will fine-tune the pretrained CodeT5 model on your dataset!
#
# **Types of Fine-tuning:**
#
# There are two common approaches to adapting pretrained models (see [Keras: Transfer Learning Guide](https://keras.io/guides/transfer_learning/)):
#
# | Approach | Description | When to Use |
# |----------|-------------|-------------|
# | **Feature Extraction** | Freeze pretrained weights, train only new head | Very small datasets, prevent overfitting |
# | **Full Fine-tuning** | Update ALL weights with low learning rate | Task differs from pretraining, enough data |
#
# **In this notebook, we use full fine-tuning** — all 220M parameters are updated. The low learning rate (5e-5) ensures small weight adjustments that preserve pretrained knowledge while adapting to MBPP.
#
# **Fine-tuning vs Training from Scratch:**
# - **From scratch** (Part A): Random initialization, train everything, needs many epochs
# - **Fine-tuning** (Part C): Start from pretrained weights, adapt to task, needs fewer epochs
#
# **Training Configuration:**
# - Learning rate: 5e-5 (lower than training from scratch to preserve pretrained knowledge)
# - Epochs: 3-5 (pretrained models converge faster)
# - Optimizer: Adam
# - Loss: Computed internally by model (sparse categorical crossentropy for tokens)
#
# **What to expect:**
# - Training loss should decrease steadily
# - Validation loss should track training loss
# - Model will learn MBPP task format
# - Generated code quality should improve dramatically over zero-shot

# %%
# ========================================
# TRAINING CONFIGURATION
# ========================================

# --- EXPERIMENT HERE: learning rate, epochs, warmup ---
LEARNING_RATE = 5e-5  # Lower learning rate for fine-tuning
EPOCHS = 5            # Fewer epochs needed for fine-tuning
WARMUP_STEPS = 100    # Gradual learning rate warmup

print(f"Training configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Epochs: {EPOCHS}")
print(f"  Warmup steps: {WARMUP_STEPS}")
print(f"  Dataset: MBPP")
print(f"  Training examples: {len(train_prompts)}")
print(f"  Validation examples: {len(val_prompts)}")
# Out:
# Training configuration:
#   Learning rate: 5e-05
#   Epochs: 5
#   Warmup steps: 100
#   Dataset: MBPP
#   Training examples: 374
#   Validation examples: 90

# %%
# ========================================
# COMPILE MODEL
# ========================================

print("Compiling model...")

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# Compile model
# Note: No loss function needed - model computes it internally from labels
model.compile(optimizer=optimizer)

print("✅ Model compiled successfully")
# Out:
# Compiling model...
# ✅ Model compiled successfully

# %%
# ========================================
# CAPTURE INITIAL WEIGHTS (before training)
# ========================================

# Save a snapshot of all trainable weights before fine-tuning
# We'll compare these against post-training weights to measure how much changed
initial_weights = {v.name: v.numpy().copy() for v in model.trainable_variables}

print(f"✅ Captured initial weights for {len(initial_weights)} trainable variables")
# Out:
# ✅ Captured initial weights for 257 trainable variables

# %%
# ========================================
# SET UP CALLBACKS
# ========================================

# Early stopping: stop if validation loss doesn't improve
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)

# Model checkpoint: save best model
model_save_path = "codet5_finetuned_mbpp.keras"
checkpoint = keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stopping, checkpoint]

print(f"✅ Callbacks configured")
print(f"  Model will be saved to: {model_save_path}")
# Out:
# ✅ Callbacks configured
#   Model will be saved to: codet5_finetuned_mbpp.keras

# %%
# ========================================
# TRAIN MODEL
# ========================================

print(f"\n{'='*80}")
print("🚀 Starting fine-tuning on MBPP dataset...")
print(f"{'='*80}\n")

history = model.fit(
    train_tf_dataset,
    validation_data=val_tf_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print(f"\n{'='*80}")
print("✅ Fine-tuning complete!")
print(f"{'='*80}")
# Out:
# ================================================================================
# 🚀 Starting fine-tuning on MBPP dataset...
# ================================================================================
#
# Epoch 1/5
# 47/47 [==============================] - ETA: 0s - loss: 0.9328
# Epoch 1: val_loss improved from inf to 0.79452, saving model to codet5_finetuned_mbpp.keras
# /usr/local/lib/python3.12/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# 47/47 [==============================] - 263s 4s/step - loss: 0.9328 - val_loss: 0.7945
# Epoch 2/5
# 47/47 [==============================] - ETA: 0s - loss: 0.6475
# Epoch 2: val_loss improved from 0.79452 to 0.76835, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 243s 5s/step - loss: 0.6475 - val_loss: 0.7684
# Epoch 3/5
# 47/47 [==============================] - ETA: 0s - loss: 0.4967
# Epoch 3: val_loss did not improve from 0.76835
# 47/47 [==============================] - 45s 955ms/step - loss: 0.4967 - val_loss: 0.7887
# Epoch 4/5
# 47/47 [==============================] - ETA: 0s - loss: 0.3944
# Epoch 4: val_loss did not improve from 0.76835
# 47/47 [==============================] - 42s 898ms/step - loss: 0.3944 - val_loss: 0.8166
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# ================================================================================
# ✅ Fine-tuning complete!
# ================================================================================

# %%
# ========================================
# PLOT TRAINING HISTORY
# ========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')

plt.title('CodeT5 Fine-tuning on MBPP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"📊 Training complete!")
print(f"  Final training loss: {history.history['loss'][-1]:.4f}")
print(f"  Final validation loss: {history.history['val_loss'][-1]:.4f}")
print(f"  Best validation loss: {min(history.history['val_loss']):.4f}")
# Out:
# 📊 Training complete!
#   Final training loss: 0.3944
#   Final validation loss: 0.8166
#   Best validation loss: 0.7684

# %% [markdown]
# ## 🔬 Step 6B: Weight Change Analysis
#
# Now that training is complete, let's **validate that fine-tuning made small, targeted changes**
# rather than drastically overwriting the pretrained knowledge.
#
# We compare the weights captured before training against the final weights and compute the
# **relative change** per variable:
#
# ```
# relative_change = ||final - initial|| / ||initial||
# ```
#
# A small value (< 0.1) indicates the pretrained knowledge is largely preserved.
# A large value would suggest catastrophic forgetting.

# %%
# ========================================
# COMPUTE WEIGHT CHANGES PER VARIABLE
# ========================================

weight_changes = {}
for v in model.trainable_variables:
    initial = initial_weights[v.name]
    final = v.numpy()
    relative_change = np.linalg.norm(final - initial) / (np.linalg.norm(initial) + 1e-8)
    weight_changes[v.name] = relative_change

changes = list(weight_changes.values())
print(f"Weight change summary across {len(changes)} trainable variables:")
print(f"  Mean relative change : {np.mean(changes):.4f}")
print(f"  Median relative change: {np.median(changes):.4f}")
print(f"  Max relative change  : {np.max(changes):.4f}")
print(f"  Min relative change  : {np.min(changes):.4f}")
# Out:
# Weight change summary across 257 trainable variables:
#   Mean relative change : 0.0153
#   Median relative change: 0.0179
#   Max relative change  : 0.0305
#   Min relative change  : 0.0001

# %%
# ========================================
# VISUALISE: TOP 20 MOST-CHANGED LAYERS
# ========================================

layer_changes = sorted(weight_changes.items(), key=lambda x: x[1], reverse=True)

# Shorten variable names for readability
names = [n.split('/')[-2] + '/' + n.split('/')[-1] for n, _ in layer_changes[:20]]
values = [v for _, v in layer_changes[:20]]

plt.figure(figsize=(12, 6))
bars = plt.barh(names[::-1], values[::-1], color='steelblue', edgecolor='black', alpha=0.7)
plt.xlabel('Relative Weight Change (||Δw|| / ||w₀||)', fontsize=12)
plt.title('Top 20 Most-Changed Variables After Fine-tuning\n(smaller = pretrained knowledge better preserved)', fontsize=13)
plt.axvline(x=0.1, color='red', linestyle='--', label='0.1 threshold')
plt.legend()
plt.tight_layout()
plt.show()

print("✅ Weight change analysis complete")
print("A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.")
# Out:
# ✅ Weight change analysis complete
# A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.

# %% [markdown]
# ## 🔍 Step 7: Evaluate Fine-Tuned Model
#
# In this step, you will test the fine-tuned model on examples!
#
# **What to expect:**
# - Better understanding of task-specific prompts (vs zero-shot)
# - Code in the correct programming language (Python)
# - More complete and accurate solutions
# - Better matching to dataset style

# %%
# ========================================
# DEFINE GENERATION FUNCTION
# ========================================

def generate_code(prompt, max_length=256, num_beams=5):
    """
    Generate code from a natural language prompt using CodeT5.

    Args:
        prompt: Natural language description of the task
        max_length: Maximum length of generated code
        num_beams: Number of beams for beam search (higher = better but slower)

    Returns:
        Generated code as a string
    """
    # Tokenize input
    inputs = tokenizer(
        prompt,
        return_tensors="tf",
        truncation=True,
        max_length=128
    )

    # Generate with beam search
    outputs = model.generate(
        inputs['input_ids'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True,
        no_repeat_ngram_size=2,  # Prevent repetition
    )

    # Decode generated tokens
    generated_code = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_code

print("✅ Generation function defined")
# Out:
# ✅ Generation function defined

# %%
# ========================================
# TEST FINE-TUNED MODEL ON SAMPLES
# ========================================

print("🧪 Testing fine-tuned model on MBPP test examples...")
print("=" * 80)

# Test on first 3 test examples
num_samples = 3

for i in range(num_samples):
    print(f"\n{'='*80}")
    print(f"Example {i+1}/{num_samples}")
    print(f"{'='*80}")

    prompt = test_prompts[i]
    expected_code = test_code[i]

    print(f"\n📝 Prompt:")
    print(prompt[:200] + ("..." if len(prompt) > 200 else ""))

    print(f"\n🎯 Expected code:")
    print(expected_code[:300] + ("..." if len(expected_code) > 300 else ""))

    print(f"\n🤖 Generated code (fine-tuned):")
    generated = generate_code(prompt, max_length=256, num_beams=5)
    print(generated[:300] + ("..." if len(generated) > 300 else ""))
    print()

print(f"{'='*80}")
print("✅ Fine-tuned evaluation complete!")
# Out:
# 🧪 Testing fine-tuned model on MBPP test examples...
# ================================================================================
#
# ================================================================================
# Example 1/3
# ================================================================================
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Expected code:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i in range(len(s) - 1,-1,-1):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     return s
#
# 🤖 Generated code (fine-tuned):
# def remove_char(str1,char):
#     temp = str1.split(char)
#
#
# ================================================================================
# Example 2/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Expected code:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated code (fine-tuned):
# def sort_matrix(matrix):
#     sum_of_rows = sum([sum(row) for row in matrix])
#
#
#
# ================================================================================
# Example 3/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Expected code:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four)
#
#
# 🤖 Generated code (fine-tuned):
# from collections import Counter
# def most_common_words(dict1):
#   dict1.sort(key = Counter(list(map(lambda x: x.split(' '), list(Counter(x).values()))))
#
# ================================================================================
# ✅ Fine-tuned evaluation complete!

# %% [markdown]
# ## 📊 Step 7B: BLEU Evaluation of Fine-Tuned CodeT5+
#
# Now let's **quantitatively evaluate** the fine-tuned model using the same methodology as Parts A and B.
#
# This will show us:
# - How much fine-tuning improved over zero-shot (Part B)
# - How CodeT5 compares to the from-scratch model (Part A)
# - The power of transfer learning + fine-tuning
#
# **Performance note:** We use **batch generation** with **greedy decoding** for speed.

# %%
# ========================================
# FINE-TUNED BLEU EVALUATION
# ========================================

# Load BLEU metric
bleu_metric = evaluate.load("bleu")

# Apply Python hints to test prompts (same as Parts A and B)
test_prompts_python = [add_python_hint(p) for p in test_prompts]

print("⚡ Generating all test codes in batches (greedy decoding for speed)...")
finetuned_generated = batch_generate_codes(  # --- EXPERIMENT HERE: batch_size, max_length, num_beams ---
    test_prompts_python,
    model=model,
    tokenizer=tokenizer,
)

# Score pre-generated codes (no inference needed — fast)
finetuned_bleu_scores, finetuned_syntax_valid, finetuned_codes, finetuned_stats = evaluate_model_with_bleu(
    test_prompts_python,
    test_code,
    None,  # generate_fn not needed — using pre-generated codes
    bleu_metric,
    model_label="Fine-Tuned CodeT5+",
    generated_codes=finetuned_generated,
)

# Analyze results with visualizations
analyze_bleu_results(
    finetuned_bleu_scores,
    finetuned_syntax_valid,
    finetuned_codes,
    test_prompts_python,
    test_code,
    finetuned_stats,
    model_label="Fine-Tuned CodeT5+"
)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# ⚡ Generating all test codes in batches (greedy decoding for speed)...
# Batch generation:   0%|          | 0/7 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Batch generation: 100%|██████████| 7/7 [01:52<00:00, 16.05s/it]
# 🔬 Scoring FINE-TUNED CODET5+ on 50 test examples (pre-generated)...
# ================================================================================
# Fine-Tuned CodeT5+ BLEU Evaluation: 100%|██████████| 50/50 [00:00<00:00, 124.68it/s]
# ================================================================================
# 📊 FINE-TUNED CODET5+ EVALUATION RESULTS
# ================================================================================
# BLEU Score (mean):        7.65
# BLEU Score (median):      1.59
# BLEU Score (std dev):     10.71
# BLEU Score (min):         0.00
# BLEU Score (max):         40.65
# Syntax Validity:          35/50 (70.0%)
# ================================================================================
#
# ✅ Fine-Tuned CodeT5+ evaluation complete!
#
# ================================================================================
# 📊 DETAILED ANALYSIS: FINE-TUNED CODET5+
# ================================================================================
# ================================================================================
# 🏆 BEST FINE-TUNED CODET5+ EXAMPLES (Highest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 - Example 42
# ================================================================================
# BLEU Score: 40.65
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to caluclate area of a parallelogram.
#
# 🎯 Reference:
# def parallelogram_area(b,h):
#   area=b*h
#   return area
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def parallelogram_area(r,a):
#  return area
#
# ================================================================================
# Rank #2 - Example 48
# ================================================================================
# BLEU Score: 39.24
# Syntax Valid: True
#
# 📝 Prompt:
# Write a python function to check whether the given two integers have opposite sign or not.
#
# 🎯 Reference:
# def opposite_Signs(x,y):
#     return ((x ^ y) < 0);
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def opposite_Sign(x,y):
#     if (x > y):
#         return True
#
# ================================================================================
# Rank #3 - Example 16
# ================================================================================
# BLEU Score: 34.62
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to check if the given tuple list has all k elements.
#
# 🎯 Reference:
# def check_k_elements(test_list, K):
#   res = True
#   for tup in test_list:
#     for ele in tup:
#       if ele != K:
#         res = False
#   return (re...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_all(test_list, K):
#   return (res)
#
# ================================================================================
# 💔 WORST FINE-TUNED CODET5+ EXAMPLES (Lowest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 from bottom - Example 1
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Reference:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i i...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def remove_char(str1,char):
#     temp = str1.find(char)
#
# ================================================================================
# Rank #2 from bottom - Example 2
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Reference:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def sum_of_rows(matrix):
#     sum = 0
#
# ================================================================================
# Rank #3 from bottom - Example 3
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Reference:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def most_common_words(d):
#   return most
#
# ================================================================================
# ✅ Fine-Tuned CodeT5+ analysis complete!
# ================================================================================

# %% [markdown]
# ## 📊 Step 8: Three-Way Model Comparison
#
# Now for the **big reveal**: Let's compare all three approaches side-by-side!
#
# - **Part A (From Scratch)**: BLEU 0.77, 0% syntax validity
# - **Part B (Zero-Shot)**: Results from Part B notebook
# - **Part C (Fine-Tuned)**: Results we just measured above
#
# **⚠️ Important**: You need to manually enter your Part B zero-shot results below.
# If you haven't run Part B yet, do that first to get the baseline numbers.

# %%
# ========================================
# ENTER YOUR PART B RESULTS HERE
# ========================================

# TODO: Replace these with your actual Part B zero-shot results
# These are example values - replace with your real results from Part B notebook
PART_B_ZEROSHOT_BLEU_MEAN = 4.24   # Replace with your actual mean BLEU from Part B
PART_B_ZEROSHOT_BLEU_MIN = 0.00    # Replace with your actual min BLEU from Part B
PART_B_ZEROSHOT_BLEU_MAX = 26.84    # Replace with your actual max BLEU from Part B
PART_B_ZEROSHOT_SYNTAX_PCT = 44.0  # Replace with your actual syntax validity % from Part B

print("⚠️  IMPORTANT: Enter your Part B zero-shot results above!")
print(f"Currently using: BLEU={PART_B_ZEROSHOT_BLEU_MEAN:.2f}, Syntax={PART_B_ZEROSHOT_SYNTAX_PCT:.1f}%")
print("These should match the output from Part B (Assignment3_PartB_Pretrained_Models.ipynb)")
# Out:
# ⚠️  IMPORTANT: Enter your Part B zero-shot results above!
# Currently using: BLEU=4.24, Syntax=44.0%
# These should match the output from Part B (Assignment3_PartB_Pretrained_Models.ipynb)

# %%
# ========================================
# THREE-WAY COMPARISON
# ========================================

import pandas as pd

# Create comparison table
comparison_data = {
    'Model': ['Part A\n(From Scratch)', 'Part B\n(Zero-Shot)', 'Part C\n(Fine-Tuned)'],
    'BLEU (mean)': [0.96, PART_B_ZEROSHOT_BLEU_MEAN, finetuned_stats['mean']],
    'BLEU (min-max)': [
        f"0.00-2.99",
        f"{PART_B_ZEROSHOT_BLEU_MIN:.2f}-{PART_B_ZEROSHOT_BLEU_MAX:.2f}",
        f"{finetuned_stats['min']:.2f}-{finetuned_stats['max']:.2f}"
    ],
    'Syntax Valid (%)': [
        0.0,
        PART_B_ZEROSHOT_SYNTAX_PCT,
        finetuned_stats['syntax_valid_pct']
    ],
    'Model Size': [
        '~1M params',
        '220M params',
        '220M params'
    ],
    'Training Data': [
        '374 MBPP',
        'Large-scale code',
        'Large-scale + 374 MBPP'
    ]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 100)
print("📊 THREE-WAY MODEL COMPARISON")
print("=" * 100)
print(comparison_df.to_string(index=False))
print("=" * 100)

# Calculate improvement factors
improvement_zeroshot = PART_B_ZEROSHOT_BLEU_MEAN / 0.96 if 0.96 > 0 and PART_B_ZEROSHOT_BLEU_MEAN > 0 else 0
improvement_finetuned = finetuned_stats['mean'] / 0.96 if 0.96 > 0 else float('inf')
improvement_ft_vs_zs = finetuned_stats['mean'] / PART_B_ZEROSHOT_BLEU_MEAN if PART_B_ZEROSHOT_BLEU_MEAN > 0 else float('inf')

print(f"\n📈 Improvement Factors:")
print(f"  Zero-shot vs From-scratch: {improvement_zeroshot:.1f}x BLEU improvement")
print(f"  Fine-tuned vs From-scratch: {improvement_finetuned:.1f}x BLEU improvement")
print(f"  Fine-tuned vs Zero-shot: {improvement_ft_vs_zs:.1f}x BLEU improvement")

# Create comparison visualizations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Chart 1: Mean BLEU Comparison
models = comparison_df['Model']
bleu_means = comparison_df['BLEU (mean)']
colors = ['#e74c3c', '#f39c12', '#2ecc71']

bars = axes[0].bar(range(len(models)), bleu_means, color=colors, alpha=0.7, edgecolor='black')
axes[0].set_xticks(range(len(models)))
axes[0].set_xticklabels(models, fontsize=10)
axes[0].set_ylabel('BLEU Score (mean)', fontsize=12)
axes[0].set_title('BLEU Score Comparison', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')
axes[0].set_ylim(0, max(bleu_means) * 1.15 if max(bleu_means) > 0 else 10)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, bleu_means)):
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2., height + max(bleu_means)*0.02,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')

# Chart 2: Syntax Validity Comparison
syntax_pcts = comparison_df['Syntax Valid (%)']

bars = axes[1].bar(range(len(models)), syntax_pcts, color=colors, alpha=0.7, edgecolor='black')
axes[1].set_xticks(range(len(models)))
axes[1].set_xticklabels(models, fontsize=10)
axes[1].set_ylabel('Syntax Validity (%)', fontsize=12)
axes[1].set_title('Syntax Validity Comparison', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')
axes[1].set_ylim(0, 105)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, syntax_pcts)):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 2,
                f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

# Chart 3: BLEU Distribution Comparison
# Note: We don't have Part B distribution, so we'll show Part A vs Part C
axes[2].hist([0.96] * 50, bins=20, alpha=0.4, label='Part A (From Scratch)', color='#e74c3c', edgecolor='black')
axes[2].hist(finetuned_bleu_scores, bins=20, alpha=0.6, label='Part C (Fine-Tuned)', color='#2ecc71', edgecolor='black')
axes[2].set_xlabel('BLEU Score', fontsize=12)
axes[2].set_ylabel('Frequency', fontsize=12)
axes[2].set_title('BLEU Score Distributions', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=10)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Three-way comparison complete!")
# Out:
# ====================================================================================================
# 📊 THREE-WAY MODEL COMPARISON
# ====================================================================================================
#                  Model  BLEU (mean) BLEU (min-max)  Syntax Valid (%)  Model Size          Training Data
# Part A\n(From Scratch)     0.960000      0.00-2.99               0.0  ~1M params               374 MBPP
#    Part B\n(Zero-Shot)     4.240000     0.00-26.84              44.0 220M params       Large-scale code
#   Part C\n(Fine-Tuned)     7.650529     0.00-40.65              70.0 220M params Large-scale + 374 MBPP
# ====================================================================================================
#
# 📈 Improvement Factors:
#   Zero-shot vs From-scratch: 4.4x BLEU improvement
#   Fine-tuned vs From-scratch: 8.0x BLEU improvement
#   Fine-tuned vs Zero-shot: 1.8x BLEU improvement
# ✅ Three-way comparison complete!

# %% [markdown]
# # Model 2

# %%
# ========================================
# LOAD CODET5 MODEL AND TOKENIZER
# ========================================

MODEL_NAME = "Salesforce/codet5p-220m-py"  # --- EXPERIMENT HERE: try other models (codet5-base, codet5p-770m, etc.) ---

print(f"Loading pretrained model: {MODEL_NAME}")
print("Note: CodeT5+ is an improved version of CodeT5 with better pretraining")
print("This may take a few minutes on first run (downloads ~250MB)...")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Load pretrained model
# Try loading TensorFlow weights directly first (no PyTorch conversion needed)
try:
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
    print("✅ Loaded from TensorFlow weights")
except Exception as e:
    print(f"TensorFlow weights not available, trying PyTorch conversion...")
    print(f"Note: This requires PyTorch to be installed")
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME, from_pt=True)

print(f"\n✅ Model and tokenizer loaded!")
print(f"Model type: {type(model).__name__}")
print(f"Tokenizer vocab size: {tokenizer.vocab_size:,}")
print(f"Model parameters: ~220M")

# ========================================
# TEST TOKENIZER ON SAMPLE
# ========================================

# Get a sample from training data
sample_prompt = train_prompts[0]
sample_code = train_code[0]

print("Sample prompt:")
print(sample_prompt[:150] + "...")
print("\nSample code:")
print(sample_code[:150] + "...")

# Tokenize
inputs = tokenizer(sample_prompt, return_tensors="tf", truncation=True, max_length=128)
targets = tokenizer(sample_code, return_tensors="tf", truncation=True, max_length=256)

print(f"\nTokenized input shape: {inputs['input_ids'].shape}")
print(f"Tokenized target shape: {targets['input_ids'].shape}")
print(f"\nFirst 20 input tokens: {inputs['input_ids'][0, :20].numpy()}")
print(f"Decoded back: {tokenizer.decode(inputs['input_ids'][0, :20], skip_special_tokens=False)}")


# ========================================
# TOKENIZATION CONFIGURATION
# ========================================

# Sequence length limits
# --- EXPERIMENT HERE: sequence lengths and batch size ---
MAX_INPUT_LENGTH = 256   # Maximum length for problem descriptions
MAX_TARGET_LENGTH = 256  # Maximum length for code solutions
BATCH_SIZE = 8           # Number of examples per batch (small due to model size)

print(f"Tokenization configuration:")
print(f"  Max input length: {MAX_INPUT_LENGTH}")
print(f"  Max target length: {MAX_TARGET_LENGTH}")
print(f"  Batch size: {BATCH_SIZE}")

# ========================================
# TOKENIZE DATASETS
# ========================================

def tokenize_function(prompts, codes):
    """
    Tokenize prompts and codes for seq2seq training.

    Args:
        prompts: List of problem descriptions
        codes: List of code solutions

    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    # Tokenize inputs (prompts)
    model_inputs = tokenizer(
        prompts,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Tokenize targets (codes)
    # Use text_target for encoder-decoder models
    labels = tokenizer(
        codes,
        max_length=MAX_TARGET_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Replace padding token id's in labels with -100 so they're ignored in loss
    labels_ids = labels['input_ids']
    labels_ids[labels_ids == tokenizer.pad_token_id] = -100

    return {
        'input_ids': model_inputs['input_ids'],
        'attention_mask': model_inputs['attention_mask'],
        'labels': labels_ids
    }

print("✅ Tokenization function defined")


# ========================================
# TOKENIZE ALL DATA AND CREATE TF DATASETS
# ========================================

print("🔄 Tokenizing all datasets...")
print("=" * 60)

# Tokenize all three splits
train_dataset = tokenize_function(train_prompts, train_code)
print(f"✅ Training data tokenized ({len(train_prompts)} examples)")
print(f"   Input shape: {train_dataset['input_ids'].shape}")
print(f"   Labels shape: {train_dataset['labels'].shape}")

val_dataset = tokenize_function(val_prompts, val_code)
print(f"✅ Validation data tokenized ({len(val_prompts)} examples)")
print(f"   Input shape: {val_dataset['input_ids'].shape}")
print(f"   Labels shape: {val_dataset['labels'].shape}")

test_dataset = tokenize_function(test_prompts, test_code)
print(f"✅ Test data tokenized ({len(test_prompts)} examples)")
print(f"   Input shape: {test_dataset['input_ids'].shape}")
print(f"   Labels shape: {test_dataset['labels'].shape}")

print("\n" + "=" * 60)
print("🔄 Creating TensorFlow datasets for training...")

# Convert to TensorFlow datasets
# IMPORTANT: For seq2seq models, labels must be in the input dictionary
train_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': train_dataset['input_ids'],
    'attention_mask': train_dataset['attention_mask'],
    'labels': train_dataset['labels']
})

val_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': val_dataset['input_ids'],
    'attention_mask': val_dataset['attention_mask'],
    'labels': val_dataset['labels']
})

# Batch and shuffle
train_tf_dataset = train_tf_dataset.shuffle(1000).batch(BATCH_SIZE)
val_tf_dataset = val_tf_dataset.batch(BATCH_SIZE)

print(f"✅ TensorFlow datasets created")
print(f"  Training batches: {len(train_tf_dataset)}")
print(f"  Validation batches: {len(val_tf_dataset)}")
print("=" * 60)

# ========================================
# TRAINING CONFIGURATION
# ========================================

# --- EXPERIMENT HERE: learning rate, epochs, warmup ---
LEARNING_RATE = 5e-5  # Lower learning rate for fine-tuning
EPOCHS = 5            # Fewer epochs needed for fine-tuning
WARMUP_STEPS = 100    # Gradual learning rate warmup

print(f"Training configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Epochs: {EPOCHS}")
print(f"  Warmup steps: {WARMUP_STEPS}")
print(f"  Dataset: MBPP")
print(f"  Training examples: {len(train_prompts)}")
print(f"  Validation examples: {len(val_prompts)}")

# ========================================
# COMPILE MODEL
# ========================================

print("Compiling model...")

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# Compile model
# Note: No loss function needed - model computes it internally from labels
model.compile(optimizer=optimizer)

print("✅ Model compiled successfully")

# ========================================
# CAPTURE INITIAL WEIGHTS (before training)
# ========================================

# Save a snapshot of all trainable weights before fine-tuning
# We'll compare these against post-training weights to measure how much changed
initial_weights = {v.name: v.numpy().copy() for v in model.trainable_variables}

print(f"✅ Captured initial weights for {len(initial_weights)} trainable variables")


# ========================================
# SET UP CALLBACKS
# ========================================

# Early stopping: stop if validation loss doesn't improve
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)

# Model checkpoint: save best model
model_save_path = "codet5_finetuned_mbpp.keras"
checkpoint = keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stopping, checkpoint]

print(f"✅ Callbacks configured")
print(f"  Model will be saved to: {model_save_path}")

# ========================================
# TRAIN MODEL
# ========================================

print(f"\n{'='*80}")
print("🚀 Starting fine-tuning on MBPP dataset...")
print(f"{'='*80}\n")

history = model.fit(
    train_tf_dataset,
    validation_data=val_tf_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print(f"\n{'='*80}")
print("✅ Fine-tuning complete!")
print(f"{'='*80}")


# ========================================
# PLOT TRAINING HISTORY
# ========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')

plt.title('CodeT5 Fine-tuning on MBPP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"📊 Training complete!")
print(f"  Final training loss: {history.history['loss'][-1]:.4f}")
print(f"  Final validation loss: {history.history['val_loss'][-1]:.4f}")
print(f"  Best validation loss: {min(history.history['val_loss']):.4f}")

# ========================================
# COMPUTE WEIGHT CHANGES PER VARIABLE
# ========================================

weight_changes = {}
for v in model.trainable_variables:
    initial = initial_weights[v.name]
    final = v.numpy()
    relative_change = np.linalg.norm(final - initial) / (np.linalg.norm(initial) + 1e-8)
    weight_changes[v.name] = relative_change

changes = list(weight_changes.values())
print(f"Weight change summary across {len(changes)} trainable variables:")
print(f"  Mean relative change : {np.mean(changes):.4f}")
print(f"  Median relative change: {np.median(changes):.4f}")
print(f"  Max relative change  : {np.max(changes):.4f}")
print(f"  Min relative change  : {np.min(changes):.4f}")


# ========================================
# VISUALISE: TOP 20 MOST-CHANGED LAYERS
# ========================================

layer_changes = sorted(weight_changes.items(), key=lambda x: x[1], reverse=True)

# Shorten variable names for readability
names = [n.split('/')[-2] + '/' + n.split('/')[-1] for n, _ in layer_changes[:20]]
values = [v for _, v in layer_changes[:20]]

plt.figure(figsize=(12, 6))
bars = plt.barh(names[::-1], values[::-1], color='steelblue', edgecolor='black', alpha=0.7)
plt.xlabel('Relative Weight Change (||Δw|| / ||w₀||)', fontsize=12)
plt.title('Top 20 Most-Changed Variables After Fine-tuning\n(smaller = pretrained knowledge better preserved)', fontsize=13)
plt.axvline(x=0.1, color='red', linestyle='--', label='0.1 threshold')
plt.legend()
plt.tight_layout()
plt.show()

print("✅ Weight change analysis complete")
print("A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.")

# ========================================
# DEFINE GENERATION FUNCTION
# ========================================

def generate_code(prompt, max_length=256, num_beams=5):
    """
    Generate code from a natural language prompt using CodeT5.

    Args:
        prompt: Natural language description of the task
        max_length: Maximum length of generated code
        num_beams: Number of beams for beam search (higher = better but slower)

    Returns:
        Generated code as a string
    """
    # Tokenize input
    inputs = tokenizer(
        prompt,
        return_tensors="tf",
        truncation=True,
        max_length=128
    )

    # Generate with beam search
    outputs = model.generate(
        inputs['input_ids'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True,
        no_repeat_ngram_size=2,  # Prevent repetition
    )

    # Decode generated tokens
    generated_code = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_code

print("✅ Generation function defined")



# ========================================
# TEST FINE-TUNED MODEL ON SAMPLES
# ========================================

print("🧪 Testing fine-tuned model on MBPP test examples...")
print("=" * 80)

# Test on first 3 test examples
num_samples = 3

for i in range(num_samples):
    print(f"\n{'='*80}")
    print(f"Example {i+1}/{num_samples}")
    print(f"{'='*80}")

    prompt = test_prompts[i]
    expected_code = test_code[i]

    print(f"\n📝 Prompt:")
    print(prompt[:200] + ("..." if len(prompt) > 200 else ""))

    print(f"\n🎯 Expected code:")
    print(expected_code[:300] + ("..." if len(expected_code) > 300 else ""))

    print(f"\n🤖 Generated code (fine-tuned):")
    generated = generate_code(prompt, max_length=256, num_beams=5)
    print(generated[:300] + ("..." if len(generated) > 300 else ""))
    print()

print(f"{'='*80}")
print("✅ Fine-tuned evaluation complete!")



# ========================================
# FINE-TUNED BLEU EVALUATION
# ========================================

# Load BLEU metric
bleu_metric = evaluate.load("bleu")

# Apply Python hints to test prompts (same as Parts A and B)
test_prompts_python = [add_python_hint(p) for p in test_prompts]

print("⚡ Generating all test codes in batches (greedy decoding for speed)...")
finetuned_generated = batch_generate_codes(  # --- EXPERIMENT HERE: batch_size, max_length, num_beams ---
    test_prompts_python,
    model=model,
    tokenizer=tokenizer,
)

# Score pre-generated codes (no inference needed — fast)
finetuned_bleu_scores, finetuned_syntax_valid, finetuned_codes, finetuned_stats = evaluate_model_with_bleu(
    test_prompts_python,
    test_code,
    None,  # generate_fn not needed — using pre-generated codes
    bleu_metric,
    model_label="Fine-Tuned CodeT5+",
    generated_codes=finetuned_generated,
)

# Analyze results with visualizations
analyze_bleu_results(
    finetuned_bleu_scores,
    finetuned_syntax_valid,
    finetuned_codes,
    test_prompts_python,
    test_code,
    finetuned_stats,
    model_label="Fine-Tuned CodeT5+"
)

# ========================================
# THREE-WAY COMPARISON
# ========================================

import pandas as pd

# Create comparison table
comparison_data = {
    'Model': ['Part A\n(From Scratch)', 'Part B\n(Zero-Shot)', 'Part C\n(Fine-Tuned)'],
    'BLEU (mean)': [0.96, PART_B_ZEROSHOT_BLEU_MEAN, finetuned_stats['mean']],
    'BLEU (min-max)': [
        f"0.00-2.99",
        f"{PART_B_ZEROSHOT_BLEU_MIN:.2f}-{PART_B_ZEROSHOT_BLEU_MAX:.2f}",
        f"{finetuned_stats['min']:.2f}-{finetuned_stats['max']:.2f}"
    ],
    'Syntax Valid (%)': [
        0.0,
        PART_B_ZEROSHOT_SYNTAX_PCT,
        finetuned_stats['syntax_valid_pct']
    ],
    'Model Size': [
        '~1M params',
        '220M params',
        '220M params'
    ],
    'Training Data': [
        '374 MBPP',
        'Large-scale code',
        'Large-scale + 374 MBPP'
    ]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 100)
print("📊 THREE-WAY MODEL COMPARISON")
print("=" * 100)
print(comparison_df.to_string(index=False))
print("=" * 100)

# Calculate improvement factors
improvement_zeroshot = PART_B_ZEROSHOT_BLEU_MEAN / 0.96 if 0.96 > 0 and PART_B_ZEROSHOT_BLEU_MEAN > 0 else 0
improvement_finetuned = finetuned_stats['mean'] / 0.96 if 0.96 > 0 else float('inf')
improvement_ft_vs_zs = finetuned_stats['mean'] / PART_B_ZEROSHOT_BLEU_MEAN if PART_B_ZEROSHOT_BLEU_MEAN > 0 else float('inf')

print(f"\n📈 Improvement Factors:")
print(f"  Zero-shot vs From-scratch: {improvement_zeroshot:.1f}x BLEU improvement")
print(f"  Fine-tuned vs From-scratch: {improvement_finetuned:.1f}x BLEU improvement")
print(f"  Fine-tuned vs Zero-shot: {improvement_ft_vs_zs:.1f}x BLEU improvement")

# Create comparison visualizations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Chart 1: Mean BLEU Comparison
models = comparison_df['Model']
bleu_means = comparison_df['BLEU (mean)']
colors = ['#e74c3c', '#f39c12', '#2ecc71']

bars = axes[0].bar(range(len(models)), bleu_means, color=colors, alpha=0.7, edgecolor='black')
axes[0].set_xticks(range(len(models)))
axes[0].set_xticklabels(models, fontsize=10)
axes[0].set_ylabel('BLEU Score (mean)', fontsize=12)
axes[0].set_title('BLEU Score Comparison', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')
axes[0].set_ylim(0, max(bleu_means) * 1.15 if max(bleu_means) > 0 else 10)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, bleu_means)):
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2., height + max(bleu_means)*0.02,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')

# Chart 2: Syntax Validity Comparison
syntax_pcts = comparison_df['Syntax Valid (%)']

bars = axes[1].bar(range(len(models)), syntax_pcts, color=colors, alpha=0.7, edgecolor='black')
axes[1].set_xticks(range(len(models)))
axes[1].set_xticklabels(models, fontsize=10)
axes[1].set_ylabel('Syntax Validity (%)', fontsize=12)
axes[1].set_title('Syntax Validity Comparison', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')
axes[1].set_ylim(0, 105)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, syntax_pcts)):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 2,
                f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

# Chart 3: BLEU Distribution Comparison
# Note: We don't have Part B distribution, so we'll show Part A vs Part C
axes[2].hist([0.96] * 50, bins=20, alpha=0.4, label='Part A (From Scratch)', color='#e74c3c', edgecolor='black')
axes[2].hist(finetuned_bleu_scores, bins=20, alpha=0.6, label='Part C (Fine-Tuned)', color='#2ecc71', edgecolor='black')
axes[2].set_xlabel('BLEU Score', fontsize=12)
axes[2].set_ylabel('Frequency', fontsize=12)
axes[2].set_title('BLEU Score Distributions', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=10)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Three-way comparison complete!")
# Out:
# Loading pretrained model: Salesforce/codet5p-220m-py
# Note: CodeT5+ is an improved version of CodeT5 with better pretraining
# This may take a few minutes on first run (downloads ~250MB)...
# TensorFlow weights not available, trying PyTorch conversion...
# Note: This requires PyTorch to be installed
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFT5ForConditionalGeneration: ['lm_head.weight', 'decoder.embed_tokens.weight', 'encoder.embed_tokens.weight']
# - This IS expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ✅ Model and tokenizer loaded!
# Model type: TFT5ForConditionalGeneration
# Tokenizer vocab size: 32,100
# Model parameters: ~220M
# Sample prompt:
# Write a function to find the longest chain which can be formed from the given set of pairs....
#
# Sample code:
# class Pair(object):
# 	def __init__(self, a, b):
# 		self.a = a
# 		self.b = b
# def max_chain_length(arr, n):
# 	max = 0
# 	mcl = [1 for i in range(n)...
#
# Tokenized input shape: (1, 21)
# Tokenized target shape: (1, 191)
#
# First 20 input tokens: [    1  3067   279   445   358  1104   326 12163  2687  1492   848   506
#  20010   628   326   864   444   434  5574    18]
# Decoded back: <s>Write a function to find the longest chain which can be formed from the given set of pairs.
# Tokenization configuration:
#   Max input length: 256
#   Max target length: 256
#   Batch size: 8
# ✅ Tokenization function defined
# 🔄 Tokenizing all datasets...
# ============================================================
# ✅ Training data tokenized (374 examples)
#    Input shape: (374, 256)
#    Labels shape: (374, 256)
# ✅ Validation data tokenized (90 examples)
#    Input shape: (90, 256)
#    Labels shape: (90, 256)
# ✅ Test data tokenized (50 examples)
#    Input shape: (50, 256)
#    Labels shape: (50, 256)
#
# ============================================================
# 🔄 Creating TensorFlow datasets for training...
# ✅ TensorFlow datasets created
#   Training batches: 47
#   Validation batches: 12
# ============================================================
# Training configuration:
#   Learning rate: 5e-05
#   Epochs: 5
#   Warmup steps: 100
#   Dataset: MBPP
#   Training examples: 374
#   Validation examples: 90
# Compiling model...
# ✅ Model compiled successfully
# ✅ Captured initial weights for 257 trainable variables
# ✅ Callbacks configured
#   Model will be saved to: codet5_finetuned_mbpp.keras
#
# ================================================================================
# 🚀 Starting fine-tuning on MBPP dataset...
# ================================================================================
#
# Epoch 1/5
# 47/47 [==============================] - ETA: 0s - loss: 0.9247
# Epoch 1: val_loss improved from inf to 0.80423, saving model to codet5_finetuned_mbpp.keras
# /usr/local/lib/python3.12/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# 47/47 [==============================] - 457s 9s/step - loss: 0.9247 - val_loss: 0.8042
# Epoch 2/5
# 47/47 [==============================] - ETA: 0s - loss: 0.6470
# Epoch 2: val_loss improved from 0.80423 to 0.77188, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 359s 8s/step - loss: 0.6470 - val_loss: 0.7719
# Epoch 3/5
# 47/47 [==============================] - ETA: 0s - loss: 0.4945
# Epoch 3: val_loss did not improve from 0.77188
# 47/47 [==============================] - 56s 1s/step - loss: 0.4945 - val_loss: 0.7896
# Epoch 4/5
# 47/47 [==============================] - ETA: 0s - loss: 0.3922
# Epoch 4: val_loss did not improve from 0.77188
# 47/47 [==============================] - 54s 1s/step - loss: 0.3922 - val_loss: 0.8312
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# ================================================================================
# ✅ Fine-tuning complete!
# ================================================================================
# 📊 Training complete!
#   Final training loss: 0.3922
#   Final validation loss: 0.8312
#   Best validation loss: 0.7719
# Weight change summary across 257 trainable variables:
#   Mean relative change : 0.0154
#   Median relative change: 0.0181
#   Max relative change  : 0.0312
#   Min relative change  : 0.0001
# ✅ Weight change analysis complete
# A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.
# ✅ Generation function defined
# 🧪 Testing fine-tuned model on MBPP test examples...
# ================================================================================
#
# ================================================================================
# Example 1/3
# ================================================================================
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Expected code:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i in range(len(s) - 1,-1,-1):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     return s
#
# 🤖 Generated code (fine-tuned):
# def remove_char(str,char):
#
#   return str
#
#
# ================================================================================
# Example 2/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Expected code:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated code (fine-tuned):
# def sort_by_sum(test_list):
#   return (res)
#
#
# ================================================================================
# Example 3/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Expected code:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four)
#
#
# 🤖 Generated code (fine-tuned):
# from collections import Counter
# def most_common_words(test_dict):
#   res = Counter(list(map(lambda x: x[1], sorted(Counter(str(x[0]).items(), key=lambda item: item[2], reverse=True))))
#
# ================================================================================
# ✅ Fine-tuned evaluation complete!
# ⚡ Generating all test codes in batches (greedy decoding for speed)...
# Batch generation: 100%|██████████| 7/7 [02:01<00:00, 17.33s/it]
# 🔬 Scoring FINE-TUNED CODET5+ on 50 test examples (pre-generated)...
# ================================================================================
# Fine-Tuned CodeT5+ BLEU Evaluation: 100%|██████████| 50/50 [00:00<00:00, 102.68it/s]
# ================================================================================
# 📊 FINE-TUNED CODET5+ EVALUATION RESULTS
# ================================================================================
# BLEU Score (mean):        10.00
# BLEU Score (median):      2.03
# BLEU Score (std dev):     14.67
# BLEU Score (min):         0.00
# BLEU Score (max):         60.56
# Syntax Validity:          40/50 (80.0%)
# ================================================================================
#
# ✅ Fine-Tuned CodeT5+ evaluation complete!
#
# ================================================================================
# 📊 DETAILED ANALYSIS: FINE-TUNED CODET5+
# ================================================================================
# ================================================================================
# 🏆 BEST FINE-TUNED CODET5+ EXAMPLES (Highest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 - Example 5
# ================================================================================
# BLEU Score: 60.56
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to split a string at lowercase letters.
#
# 🎯 Reference:
# import re
# def split_lowerstring(text):
#  return (re.findall('[a-z][^a-z]*', text))
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# import re
# def split_text(text):
#   return (re.findall('[A-Z]', text))
#
# ================================================================================
# Rank #2 - Example 31
# ================================================================================
# BLEU Score: 46.34
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to filter even numbers using lambda function.
#
# 🎯 Reference:
# def filter_evennumbers(nums):
#  even_nums = list(filter(lambda x: x%2 == 0, nums))
#  return even_nums
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def even_num(num):
#   return list(filter(lambda x: x%2==0, num))
#
# ================================================================================
# Rank #3 - Example 16
# ================================================================================
# BLEU Score: 40.49
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to check if the given tuple list has all k elements.
#
# 🎯 Reference:
# def check_k_elements(test_list, K):
#   res = True
#   for tup in test_list:
#     for ele in tup:
#       if ele != K:
#         res = False
#   return (re...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_all_elements(test_list, K):
#   return (res)
#
# ================================================================================
# 💔 WORST FINE-TUNED CODET5+ EXAMPLES (Lowest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 from bottom - Example 1
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Reference:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i i...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def remove_char(str,char):
#     str = str.replace(char, '', 1)
#
# ================================================================================
# Rank #2 from bottom - Example 4
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Write a python function to find the volume of a triangular prism.
#
# 🎯 Reference:
# def find_Volume(l,b,h) :
#     return ((l * b * h) / 2)
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def volume_Triangular_Prism(a,b,c):
#     volume = (a*b*c)
#
# ================================================================================
# Rank #3 from bottom - Example 7
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to find the perimeter of a square.
#
# 🎯 Reference:
# def square_perimeter(a):
#   perimeter=4*a
#   return perimeter
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def perimeter_Square(r,a):
#  perim = (r*a)
#
# ================================================================================
# ✅ Fine-Tuned CodeT5+ analysis complete!
# ================================================================================
#
# ====================================================================================================
# 📊 THREE-WAY MODEL COMPARISON
# ====================================================================================================
#                  Model  BLEU (mean) BLEU (min-max)  Syntax Valid (%)  Model Size          Training Data
# Part A\n(From Scratch)     0.960000      0.00-2.99               0.0  ~1M params               374 MBPP
#    Part B\n(Zero-Shot)     4.240000     0.00-26.84              44.0 220M params       Large-scale code
#   Part C\n(Fine-Tuned)     9.998286     0.00-60.56              80.0 220M params Large-scale + 374 MBPP
# ====================================================================================================
#
# 📈 Improvement Factors:
#   Zero-shot vs From-scratch: 4.4x BLEU improvement
#   Fine-tuned vs From-scratch: 10.4x BLEU improvement
#   Fine-tuned vs Zero-shot: 2.4x BLEU improvement
# ✅ Three-way comparison complete!

# %% [markdown]
# # Model 3

# %%
# ========================================
# LOAD CODET5 MODEL AND TOKENIZER
# ========================================

MODEL_NAME = "Salesforce/codet5p-220m-py"  # --- EXPERIMENT HERE: try other models (codet5-base, codet5p-770m, etc.) ---

print(f"Loading pretrained model: {MODEL_NAME}")
print("Note: CodeT5+ is an improved version of CodeT5 with better pretraining")
print("This may take a few minutes on first run (downloads ~250MB)...")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Load pretrained model
# Try loading TensorFlow weights directly first (no PyTorch conversion needed)
try:
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
    print("✅ Loaded from TensorFlow weights")
except Exception as e:
    print(f"TensorFlow weights not available, trying PyTorch conversion...")
    print(f"Note: This requires PyTorch to be installed")
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME, from_pt=True)

print(f"\n✅ Model and tokenizer loaded!")
print(f"Model type: {type(model).__name__}")
print(f"Tokenizer vocab size: {tokenizer.vocab_size:,}")
print(f"Model parameters: ~220M")

# ========================================
# TEST TOKENIZER ON SAMPLE
# ========================================

# Get a sample from training data
sample_prompt = train_prompts[0]
sample_code = train_code[0]

print("Sample prompt:")
print(sample_prompt[:150] + "...")
print("\nSample code:")
print(sample_code[:150] + "...")

# Tokenize
inputs = tokenizer(sample_prompt, return_tensors="tf", truncation=True, max_length=128)
targets = tokenizer(sample_code, return_tensors="tf", truncation=True, max_length=256)

print(f"\nTokenized input shape: {inputs['input_ids'].shape}")
print(f"Tokenized target shape: {targets['input_ids'].shape}")
print(f"\nFirst 20 input tokens: {inputs['input_ids'][0, :20].numpy()}")
print(f"Decoded back: {tokenizer.decode(inputs['input_ids'][0, :20], skip_special_tokens=False)}")


# ========================================
# TOKENIZATION CONFIGURATION
# ========================================

# Sequence length limits
# --- EXPERIMENT HERE: sequence lengths and batch size ---
MAX_INPUT_LENGTH = 64   # Maximum length for problem descriptions
MAX_TARGET_LENGTH = 32  # Maximum length for code solutions
BATCH_SIZE = 4           # Number of examples per batch (small due to model size)

print(f"Tokenization configuration:")
print(f"  Max input length: {MAX_INPUT_LENGTH}")
print(f"  Max target length: {MAX_TARGET_LENGTH}")
print(f"  Batch size: {BATCH_SIZE}")

# ========================================
# TOKENIZE DATASETS
# ========================================

def tokenize_function(prompts, codes):
    """
    Tokenize prompts and codes for seq2seq training.

    Args:
        prompts: List of problem descriptions
        codes: List of code solutions

    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    # Tokenize inputs (prompts)
    model_inputs = tokenizer(
        prompts,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Tokenize targets (codes)
    # Use text_target for encoder-decoder models
    labels = tokenizer(
        codes,
        max_length=MAX_TARGET_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Replace padding token id's in labels with -100 so they're ignored in loss
    labels_ids = labels['input_ids']
    labels_ids[labels_ids == tokenizer.pad_token_id] = -100

    return {
        'input_ids': model_inputs['input_ids'],
        'attention_mask': model_inputs['attention_mask'],
        'labels': labels_ids
    }

print("✅ Tokenization function defined")


# ========================================
# TOKENIZE ALL DATA AND CREATE TF DATASETS
# ========================================

print("🔄 Tokenizing all datasets...")
print("=" * 60)

# Tokenize all three splits
train_dataset = tokenize_function(train_prompts, train_code)
print(f"✅ Training data tokenized ({len(train_prompts)} examples)")
print(f"   Input shape: {train_dataset['input_ids'].shape}")
print(f"   Labels shape: {train_dataset['labels'].shape}")

val_dataset = tokenize_function(val_prompts, val_code)
print(f"✅ Validation data tokenized ({len(val_prompts)} examples)")
print(f"   Input shape: {val_dataset['input_ids'].shape}")
print(f"   Labels shape: {val_dataset['labels'].shape}")

test_dataset = tokenize_function(test_prompts, test_code)
print(f"✅ Test data tokenized ({len(test_prompts)} examples)")
print(f"   Input shape: {test_dataset['input_ids'].shape}")
print(f"   Labels shape: {test_dataset['labels'].shape}")

print("\n" + "=" * 60)
print("🔄 Creating TensorFlow datasets for training...")

# Convert to TensorFlow datasets
# IMPORTANT: For seq2seq models, labels must be in the input dictionary
train_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': train_dataset['input_ids'],
    'attention_mask': train_dataset['attention_mask'],
    'labels': train_dataset['labels']
})

val_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': val_dataset['input_ids'],
    'attention_mask': val_dataset['attention_mask'],
    'labels': val_dataset['labels']
})

# Batch and shuffle
train_tf_dataset = train_tf_dataset.shuffle(1000).batch(BATCH_SIZE)
val_tf_dataset = val_tf_dataset.batch(BATCH_SIZE)

print(f"✅ TensorFlow datasets created")
print(f"  Training batches: {len(train_tf_dataset)}")
print(f"  Validation batches: {len(val_tf_dataset)}")
print("=" * 60)

# ========================================
# TRAINING CONFIGURATION
# ========================================

# --- EXPERIMENT HERE: learning rate, epochs, warmup ---
LEARNING_RATE = 5e-3  # Lower learning rate for fine-tuning
EPOCHS = 15            # Fewer epochs needed for fine-tuning
WARMUP_STEPS = 100    # Gradual learning rate warmup

print(f"Training configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Epochs: {EPOCHS}")
print(f"  Warmup steps: {WARMUP_STEPS}")
print(f"  Dataset: MBPP")
print(f"  Training examples: {len(train_prompts)}")
print(f"  Validation examples: {len(val_prompts)}")

# ========================================
# COMPILE MODEL
# ========================================

print("Compiling model...")

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# Compile model
# Note: No loss function needed - model computes it internally from labels
model.compile(optimizer=optimizer)

print("✅ Model compiled successfully")

# ========================================
# CAPTURE INITIAL WEIGHTS (before training)
# ========================================

# Save a snapshot of all trainable weights before fine-tuning
# We'll compare these against post-training weights to measure how much changed
initial_weights = {v.name: v.numpy().copy() for v in model.trainable_variables}

print(f"✅ Captured initial weights for {len(initial_weights)} trainable variables")


# ========================================
# SET UP CALLBACKS
# ========================================

# Early stopping: stop if validation loss doesn't improve
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)

# Model checkpoint: save best model
model_save_path = "codet5_finetuned_mbpp.keras"
checkpoint = keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stopping, checkpoint]

print(f"✅ Callbacks configured")
print(f"  Model will be saved to: {model_save_path}")

# ========================================
# TRAIN MODEL
# ========================================

print(f"\n{'='*80}")
print("🚀 Starting fine-tuning on MBPP dataset...")
print(f"{'='*80}\n")

history = model.fit(
    train_tf_dataset,
    validation_data=val_tf_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print(f"\n{'='*80}")
print("✅ Fine-tuning complete!")
print(f"{'='*80}")


# ========================================
# PLOT TRAINING HISTORY
# ========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')

plt.title('CodeT5 Fine-tuning on MBPP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"📊 Training complete!")
print(f"  Final training loss: {history.history['loss'][-1]:.4f}")
print(f"  Final validation loss: {history.history['val_loss'][-1]:.4f}")
print(f"  Best validation loss: {min(history.history['val_loss']):.4f}")

# ========================================
# COMPUTE WEIGHT CHANGES PER VARIABLE
# ========================================

weight_changes = {}
for v in model.trainable_variables:
    initial = initial_weights[v.name]
    final = v.numpy()
    relative_change = np.linalg.norm(final - initial) / (np.linalg.norm(initial) + 1e-8)
    weight_changes[v.name] = relative_change

changes = list(weight_changes.values())
print(f"Weight change summary across {len(changes)} trainable variables:")
print(f"  Mean relative change : {np.mean(changes):.4f}")
print(f"  Median relative change: {np.median(changes):.4f}")
print(f"  Max relative change  : {np.max(changes):.4f}")
print(f"  Min relative change  : {np.min(changes):.4f}")


# ========================================
# VISUALISE: TOP 20 MOST-CHANGED LAYERS
# ========================================

layer_changes = sorted(weight_changes.items(), key=lambda x: x[1], reverse=True)

# Shorten variable names for readability
names = [n.split('/')[-2] + '/' + n.split('/')[-1] for n, _ in layer_changes[:20]]
values = [v for _, v in layer_changes[:20]]

plt.figure(figsize=(12, 6))
bars = plt.barh(names[::-1], values[::-1], color='steelblue', edgecolor='black', alpha=0.7)
plt.xlabel('Relative Weight Change (||Δw|| / ||w₀||)', fontsize=12)
plt.title('Top 20 Most-Changed Variables After Fine-tuning\n(smaller = pretrained knowledge better preserved)', fontsize=13)
plt.axvline(x=0.1, color='red', linestyle='--', label='0.1 threshold')
plt.legend()
plt.tight_layout()
plt.show()

print("✅ Weight change analysis complete")
print("A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.")

# ========================================
# DEFINE GENERATION FUNCTION
# ========================================

def generate_code(prompt, max_length=256, num_beams=5):
    """
    Generate code from a natural language prompt using CodeT5.

    Args:
        prompt: Natural language description of the task
        max_length: Maximum length of generated code
        num_beams: Number of beams for beam search (higher = better but slower)

    Returns:
        Generated code as a string
    """
    # Tokenize input
    inputs = tokenizer(
        prompt,
        return_tensors="tf",
        truncation=True,
        max_length=128
    )

    # Generate with beam search
    outputs = model.generate(
        inputs['input_ids'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True,
        no_repeat_ngram_size=2,  # Prevent repetition
    )

    # Decode generated tokens
    generated_code = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_code

print("✅ Generation function defined")



# ========================================
# TEST FINE-TUNED MODEL ON SAMPLES
# ========================================

print("🧪 Testing fine-tuned model on MBPP test examples...")
print("=" * 80)

# Test on first 3 test examples
num_samples = 3

for i in range(num_samples):
    print(f"\n{'='*80}")
    print(f"Example {i+1}/{num_samples}")
    print(f"{'='*80}")

    prompt = test_prompts[i]
    expected_code = test_code[i]

    print(f"\n📝 Prompt:")
    print(prompt[:200] + ("..." if len(prompt) > 200 else ""))

    print(f"\n🎯 Expected code:")
    print(expected_code[:300] + ("..." if len(expected_code) > 300 else ""))

    print(f"\n🤖 Generated code (fine-tuned):")
    generated = generate_code(prompt, max_length=256, num_beams=5)
    print(generated[:300] + ("..." if len(generated) > 300 else ""))
    print()

print(f"{'='*80}")
print("✅ Fine-tuned evaluation complete!")



# ========================================
# FINE-TUNED BLEU EVALUATION
# ========================================

# Load BLEU metric
bleu_metric = evaluate.load("bleu")

# Apply Python hints to test prompts (same as Parts A and B)
test_prompts_python = [add_python_hint(p) for p in test_prompts]

print("⚡ Generating all test codes in batches (greedy decoding for speed)...")
finetuned_generated = batch_generate_codes(  # --- EXPERIMENT HERE: batch_size, max_length, num_beams ---
    test_prompts_python,
    model=model,
    tokenizer=tokenizer,
)

# Score pre-generated codes (no inference needed — fast)
finetuned_bleu_scores, finetuned_syntax_valid, finetuned_codes, finetuned_stats = evaluate_model_with_bleu(
    test_prompts_python,
    test_code,
    None,  # generate_fn not needed — using pre-generated codes
    bleu_metric,
    model_label="Fine-Tuned CodeT5+",
    generated_codes=finetuned_generated,
)

# Analyze results with visualizations
analyze_bleu_results(
    finetuned_bleu_scores,
    finetuned_syntax_valid,
    finetuned_codes,
    test_prompts_python,
    test_code,
    finetuned_stats,
    model_label="Fine-Tuned CodeT5+"
)

# ========================================
# THREE-WAY COMPARISON
# ========================================

import pandas as pd

# Create comparison table
comparison_data = {
    'Model': ['Part A\n(From Scratch)', 'Part B\n(Zero-Shot)', 'Part C\n(Fine-Tuned)'],
    'BLEU (mean)': [0.96, PART_B_ZEROSHOT_BLEU_MEAN, finetuned_stats['mean']],
    'BLEU (min-max)': [
        f"0.00-2.99",
        f"{PART_B_ZEROSHOT_BLEU_MIN:.2f}-{PART_B_ZEROSHOT_BLEU_MAX:.2f}",
        f"{finetuned_stats['min']:.2f}-{finetuned_stats['max']:.2f}"
    ],
    'Syntax Valid (%)': [
        0.0,
        PART_B_ZEROSHOT_SYNTAX_PCT,
        finetuned_stats['syntax_valid_pct']
    ],
    'Model Size': [
        '~1M params',
        '220M params',
        '220M params'
    ],
    'Training Data': [
        '374 MBPP',
        'Large-scale code',
        'Large-scale + 374 MBPP'
    ]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 100)
print("📊 THREE-WAY MODEL COMPARISON")
print("=" * 100)
print(comparison_df.to_string(index=False))
print("=" * 100)

# Calculate improvement factors
improvement_zeroshot = PART_B_ZEROSHOT_BLEU_MEAN / 0.96 if 0.96 > 0 and PART_B_ZEROSHOT_BLEU_MEAN > 0 else 0
improvement_finetuned = finetuned_stats['mean'] / 0.96 if 0.96 > 0 else float('inf')
improvement_ft_vs_zs = finetuned_stats['mean'] / PART_B_ZEROSHOT_BLEU_MEAN if PART_B_ZEROSHOT_BLEU_MEAN > 0 else float('inf')

print(f"\n📈 Improvement Factors:")
print(f"  Zero-shot vs From-scratch: {improvement_zeroshot:.1f}x BLEU improvement")
print(f"  Fine-tuned vs From-scratch: {improvement_finetuned:.1f}x BLEU improvement")
print(f"  Fine-tuned vs Zero-shot: {improvement_ft_vs_zs:.1f}x BLEU improvement")

# Create comparison visualizations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Chart 1: Mean BLEU Comparison
models = comparison_df['Model']
bleu_means = comparison_df['BLEU (mean)']
colors = ['#e74c3c', '#f39c12', '#2ecc71']

bars = axes[0].bar(range(len(models)), bleu_means, color=colors, alpha=0.7, edgecolor='black')
axes[0].set_xticks(range(len(models)))
axes[0].set_xticklabels(models, fontsize=10)
axes[0].set_ylabel('BLEU Score (mean)', fontsize=12)
axes[0].set_title('BLEU Score Comparison', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')
axes[0].set_ylim(0, max(bleu_means) * 1.15 if max(bleu_means) > 0 else 10)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, bleu_means)):
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2., height + max(bleu_means)*0.02,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')

# Chart 2: Syntax Validity Comparison
syntax_pcts = comparison_df['Syntax Valid (%)']

bars = axes[1].bar(range(len(models)), syntax_pcts, color=colors, alpha=0.7, edgecolor='black')
axes[1].set_xticks(range(len(models)))
axes[1].set_xticklabels(models, fontsize=10)
axes[1].set_ylabel('Syntax Validity (%)', fontsize=12)
axes[1].set_title('Syntax Validity Comparison', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')
axes[1].set_ylim(0, 105)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, syntax_pcts)):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 2,
                f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

# Chart 3: BLEU Distribution Comparison
# Note: We don't have Part B distribution, so we'll show Part A vs Part C
axes[2].hist([0.96] * 50, bins=20, alpha=0.4, label='Part A (From Scratch)', color='#e74c3c', edgecolor='black')
axes[2].hist(finetuned_bleu_scores, bins=20, alpha=0.6, label='Part C (Fine-Tuned)', color='#2ecc71', edgecolor='black')
axes[2].set_xlabel('BLEU Score', fontsize=12)
axes[2].set_ylabel('Frequency', fontsize=12)
axes[2].set_title('BLEU Score Distributions', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=10)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Three-way comparison complete!")
# Out:
# Loading pretrained model: Salesforce/codet5p-220m-py
# Note: CodeT5+ is an improved version of CodeT5 with better pretraining
# This may take a few minutes on first run (downloads ~250MB)...
# TensorFlow weights not available, trying PyTorch conversion...
# Note: This requires PyTorch to be installed
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFT5ForConditionalGeneration: ['lm_head.weight', 'decoder.embed_tokens.weight', 'encoder.embed_tokens.weight']
# - This IS expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ✅ Model and tokenizer loaded!
# Model type: TFT5ForConditionalGeneration
# Tokenizer vocab size: 32,100
# Model parameters: ~220M
# Sample prompt:
# Write a function to find the longest chain which can be formed from the given set of pairs....
#
# Sample code:
# class Pair(object):
# 	def __init__(self, a, b):
# 		self.a = a
# 		self.b = b
# def max_chain_length(arr, n):
# 	max = 0
# 	mcl = [1 for i in range(n)...
#
# Tokenized input shape: (1, 21)
# Tokenized target shape: (1, 191)
#
# First 20 input tokens: [    1  3067   279   445   358  1104   326 12163  2687  1492   848   506
#  20010   628   326   864   444   434  5574    18]
# Decoded back: <s>Write a function to find the longest chain which can be formed from the given set of pairs.
# Tokenization configuration:
#   Max input length: 64
#   Max target length: 32
#   Batch size: 4
# ✅ Tokenization function defined
# 🔄 Tokenizing all datasets...
# ============================================================
# ✅ Training data tokenized (374 examples)
#    Input shape: (374, 64)
#    Labels shape: (374, 32)
# ✅ Validation data tokenized (90 examples)
#    Input shape: (90, 64)
#    Labels shape: (90, 32)
# ✅ Test data tokenized (50 examples)
#    Input shape: (50, 64)
#    Labels shape: (50, 32)
#
# ============================================================
# 🔄 Creating TensorFlow datasets for training...
# ✅ TensorFlow datasets created
#   Training batches: 94
#   Validation batches: 23
# ============================================================
# Training configuration:
#   Learning rate: 0.005
#   Epochs: 15
#   Warmup steps: 100
#   Dataset: MBPP
#   Training examples: 374
#   Validation examples: 90
# Compiling model...
# ✅ Model compiled successfully
# ✅ Captured initial weights for 257 trainable variables
# ✅ Callbacks configured
#   Model will be saved to: codet5_finetuned_mbpp.keras
#
# ================================================================================
# 🚀 Starting fine-tuning on MBPP dataset...
# ================================================================================
#
# Epoch 1/15
# 94/94 [==============================] - ETA: 0s - loss: 5.7815
# Epoch 1: val_loss improved from inf to 5.31195, saving model to codet5_finetuned_mbpp.keras
# /usr/local/lib/python3.12/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# 94/94 [==============================] - 581s 6s/step - loss: 5.7815 - val_loss: 5.3119
# Epoch 2/15
# 94/94 [==============================] - ETA: 0s - loss: 4.4899
# Epoch 2: val_loss improved from 5.31195 to 4.09529, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 517s 6s/step - loss: 4.4899 - val_loss: 4.0953
# Epoch 3/15
# 94/94 [==============================] - ETA: 0s - loss: 3.7866
# Epoch 3: val_loss improved from 4.09529 to 3.85001, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 1040s 11s/step - loss: 3.7866 - val_loss: 3.8500
# Epoch 4/15
# 94/94 [==============================] - ETA: 0s - loss: 3.6451
# Epoch 4: val_loss did not improve from 3.85001
# 94/94 [==============================] - 20s 212ms/step - loss: 3.6451 - val_loss: 3.8851
# Epoch 5/15
# 94/94 [==============================] - ETA: 0s - loss: 3.5389
# Epoch 5: val_loss did not improve from 3.85001
# 94/94 [==============================] - 20s 215ms/step - loss: 3.5389 - val_loss: 3.8616
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# ================================================================================
# ✅ Fine-tuning complete!
# ================================================================================
# 📊 Training complete!
#   Final training loss: 3.5389
#   Final validation loss: 3.8616
#   Best validation loss: 3.8500
# Weight change summary across 257 trainable variables:
#   Mean relative change : 1.2506
#   Median relative change: 1.3945
#   Max relative change  : 4.0309
#   Min relative change  : 0.0245
# ✅ Weight change analysis complete
# A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.
# ✅ Generation function defined
# 🧪 Testing fine-tuned model on MBPP test examples...
# ================================================================================
#
# ================================================================================
# Example 1/3
# ================================================================================
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Expected code:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i in range(len(s) - 1,-1,-1):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     return s
#
# 🤖 Generated code (fine-tuned):
# def check_list):
#
#
#
# ================================================================================
# Example 2/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Expected code:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated code (fine-tuned):
# def check_list):
#
#
#
# ================================================================================
# Example 3/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Expected code:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four)
#
#
# 🤖 Generated code (fine-tuned):
# def check_list):
#
#
# ================================================================================
# ✅ Fine-tuned evaluation complete!
# ⚡ Generating all test codes in batches (greedy decoding for speed)...
# Batch generation: 100%|██████████| 7/7 [00:29<00:00,  4.25s/it]
# 🔬 Scoring FINE-TUNED CODET5+ on 50 test examples (pre-generated)...
# ================================================================================
# Fine-Tuned CodeT5+ BLEU Evaluation: 100%|██████████| 50/50 [00:00<00:00, 138.91it/s]
# ================================================================================
# 📊 FINE-TUNED CODET5+ EVALUATION RESULTS
# ================================================================================
# BLEU Score (mean):        0.00
# BLEU Score (median):      0.00
# BLEU Score (std dev):     0.00
# BLEU Score (min):         0.00
# BLEU Score (max):         0.03
# Syntax Validity:          0/50 (0.0%)
# ================================================================================
#
# ✅ Fine-Tuned CodeT5+ evaluation complete!
#
# ================================================================================
# 📊 DETAILED ANALYSIS: FINE-TUNED CODET5+
# ================================================================================
# ================================================================================
# 🏆 BEST FINE-TUNED CODET5+ EXAMPLES (Highest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 - Example 40
# ================================================================================
# BLEU Score: 0.03
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to find the list with minimum length using lambda function.
#
# 🎯 Reference:
# def min_length_list(input_list):
#     min_length = min(len(x) for x in input_list )
#     min_list = min(input_list, key = lambda i: len(i))
#     ret...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_list):
#     return
#
# ================================================================================
# Rank #2 - Example 27
# ================================================================================
# BLEU Score: 0.01
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to sort a given mixed list of integers and strings.
#
# 🎯 Reference:
# def sort_mixed_list(mixed_list):
#     int_part = sorted([i for i in mixed_list if type(i) is int])
#     str_part = sorted([i for i in mixed_list if ty...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_list):
#     return
#
# ================================================================================
# Rank #3 - Example 44
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to sort the given array by using counting sort.
#
# 🎯 Reference:
# def counting_sort(my_list):
#     max_value = 0
#     for i in range(len(my_list)):
#         if my_list[i] > max_value:
#             max_value = my_list...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_list):
#     return
#
# ================================================================================
# 💔 WORST FINE-TUNED CODET5+ EXAMPLES (Lowest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 from bottom - Example 1
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Reference:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i i...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_list):
#     return
#
# ================================================================================
# Rank #2 from bottom - Example 2
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Reference:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_list):
#     return
#
# ================================================================================
# Rank #3 from bottom - Example 3
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Reference:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_list):
#     return
#
# ================================================================================
# ✅ Fine-Tuned CodeT5+ analysis complete!
# ================================================================================
#
# ====================================================================================================
# 📊 THREE-WAY MODEL COMPARISON
# ====================================================================================================
#                  Model  BLEU (mean) BLEU (min-max)  Syntax Valid (%)  Model Size          Training Data
# Part A\n(From Scratch)      0.96000      0.00-2.99               0.0  ~1M params               374 MBPP
#    Part B\n(Zero-Shot)      4.24000     0.00-26.84              44.0 220M params       Large-scale code
#   Part C\n(Fine-Tuned)      0.00074      0.00-0.03               0.0 220M params Large-scale + 374 MBPP
# ====================================================================================================
#
# 📈 Improvement Factors:
#   Zero-shot vs From-scratch: 4.4x BLEU improvement
#   Fine-tuned vs From-scratch: 0.0x BLEU improvement
#   Fine-tuned vs Zero-shot: 0.0x BLEU improvement
# ✅ Three-way comparison complete!

# %% [markdown]
# # Model 4

# %%
# ========================================
# LOAD CODET5 MODEL AND TOKENIZER
# ========================================

MODEL_NAME = "Salesforce/codet5-base"  # --- EXPERIMENT HERE: try other models (codet5-base, codet5p-770m, etc.) ---

print(f"Loading pretrained model: {MODEL_NAME}")
print("Note: CodeT5+ is an improved version of CodeT5 with better pretraining")
print("This may take a few minutes on first run (downloads ~250MB)...")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Load pretrained model
# Try loading TensorFlow weights directly first (no PyTorch conversion needed)
try:
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
    print("✅ Loaded from TensorFlow weights")
except Exception as e:
    print(f"TensorFlow weights not available, trying PyTorch conversion...")
    print(f"Note: This requires PyTorch to be installed")
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME, from_pt=True)

print(f"\n✅ Model and tokenizer loaded!")
print(f"Model type: {type(model).__name__}")
print(f"Tokenizer vocab size: {tokenizer.vocab_size:,}")
print(f"Model parameters: ~220M")

# ========================================
# TEST TOKENIZER ON SAMPLE
# ========================================

# Get a sample from training data
sample_prompt = train_prompts[0]
sample_code = train_code[0]

print("Sample prompt:")
print(sample_prompt[:150] + "...")
print("\nSample code:")
print(sample_code[:150] + "...")

# Tokenize
inputs = tokenizer(sample_prompt, return_tensors="tf", truncation=True, max_length=128)
targets = tokenizer(sample_code, return_tensors="tf", truncation=True, max_length=256)

print(f"\nTokenized input shape: {inputs['input_ids'].shape}")
print(f"Tokenized target shape: {targets['input_ids'].shape}")
print(f"\nFirst 20 input tokens: {inputs['input_ids'][0, :20].numpy()}")
print(f"Decoded back: {tokenizer.decode(inputs['input_ids'][0, :20], skip_special_tokens=False)}")


# ========================================
# TOKENIZATION CONFIGURATION
# ========================================

# Sequence length limits
# --- EXPERIMENT HERE: sequence lengths and batch size ---
MAX_INPUT_LENGTH = 128   # Maximum length for problem descriptions
MAX_TARGET_LENGTH = 128  # Maximum length for code solutions
BATCH_SIZE = 4           # Number of examples per batch (small due to model size)

print(f"Tokenization configuration:")
print(f"  Max input length: {MAX_INPUT_LENGTH}")
print(f"  Max target length: {MAX_TARGET_LENGTH}")
print(f"  Batch size: {BATCH_SIZE}")

# ========================================
# TOKENIZE DATASETS
# ========================================

def tokenize_function(prompts, codes):
    """
    Tokenize prompts and codes for seq2seq training.

    Args:
        prompts: List of problem descriptions
        codes: List of code solutions

    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    # Tokenize inputs (prompts)
    model_inputs = tokenizer(
        prompts,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Tokenize targets (codes)
    # Use text_target for encoder-decoder models
    labels = tokenizer(
        codes,
        max_length=MAX_TARGET_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Replace padding token id's in labels with -100 so they're ignored in loss
    labels_ids = labels['input_ids']
    labels_ids[labels_ids == tokenizer.pad_token_id] = -100

    return {
        'input_ids': model_inputs['input_ids'],
        'attention_mask': model_inputs['attention_mask'],
        'labels': labels_ids
    }

print("✅ Tokenization function defined")


# ========================================
# TOKENIZE ALL DATA AND CREATE TF DATASETS
# ========================================

print("🔄 Tokenizing all datasets...")
print("=" * 60)

# Tokenize all three splits
train_dataset = tokenize_function(train_prompts, train_code)
print(f"✅ Training data tokenized ({len(train_prompts)} examples)")
print(f"   Input shape: {train_dataset['input_ids'].shape}")
print(f"   Labels shape: {train_dataset['labels'].shape}")

val_dataset = tokenize_function(val_prompts, val_code)
print(f"✅ Validation data tokenized ({len(val_prompts)} examples)")
print(f"   Input shape: {val_dataset['input_ids'].shape}")
print(f"   Labels shape: {val_dataset['labels'].shape}")

test_dataset = tokenize_function(test_prompts, test_code)
print(f"✅ Test data tokenized ({len(test_prompts)} examples)")
print(f"   Input shape: {test_dataset['input_ids'].shape}")
print(f"   Labels shape: {test_dataset['labels'].shape}")

print("\n" + "=" * 60)
print("🔄 Creating TensorFlow datasets for training...")

# Convert to TensorFlow datasets
# IMPORTANT: For seq2seq models, labels must be in the input dictionary
train_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': train_dataset['input_ids'],
    'attention_mask': train_dataset['attention_mask'],
    'labels': train_dataset['labels']
})

val_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': val_dataset['input_ids'],
    'attention_mask': val_dataset['attention_mask'],
    'labels': val_dataset['labels']
})

# Batch and shuffle
train_tf_dataset = train_tf_dataset.shuffle(1000).batch(BATCH_SIZE)
val_tf_dataset = val_tf_dataset.batch(BATCH_SIZE)

print(f"✅ TensorFlow datasets created")
print(f"  Training batches: {len(train_tf_dataset)}")
print(f"  Validation batches: {len(val_tf_dataset)}")
print("=" * 60)

# ========================================
# TRAINING CONFIGURATION
# ========================================

# --- EXPERIMENT HERE: learning rate, epochs, warmup ---
LEARNING_RATE = 5e-3  # Lower learning rate for fine-tuning
EPOCHS = 10            # Fewer epochs needed for fine-tuning
WARMUP_STEPS = 100    # Gradual learning rate warmup

print(f"Training configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Epochs: {EPOCHS}")
print(f"  Warmup steps: {WARMUP_STEPS}")
print(f"  Dataset: MBPP")
print(f"  Training examples: {len(train_prompts)}")
print(f"  Validation examples: {len(val_prompts)}")

# ========================================
# COMPILE MODEL
# ========================================

print("Compiling model...")

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# Compile model
# Note: No loss function needed - model computes it internally from labels
model.compile(optimizer=optimizer)

print("✅ Model compiled successfully")

# ========================================
# CAPTURE INITIAL WEIGHTS (before training)
# ========================================

# Save a snapshot of all trainable weights before fine-tuning
# We'll compare these against post-training weights to measure how much changed
initial_weights = {v.name: v.numpy().copy() for v in model.trainable_variables}

print(f"✅ Captured initial weights for {len(initial_weights)} trainable variables")


# ========================================
# SET UP CALLBACKS
# ========================================

# Early stopping: stop if validation loss doesn't improve
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)

# Model checkpoint: save best model
model_save_path = "codet5_finetuned_mbpp.keras"
checkpoint = keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stopping, checkpoint]

print(f"✅ Callbacks configured")
print(f"  Model will be saved to: {model_save_path}")

# ========================================
# TRAIN MODEL
# ========================================

print(f"\n{'='*80}")
print("🚀 Starting fine-tuning on MBPP dataset...")
print(f"{'='*80}\n")

history = model.fit(
    train_tf_dataset,
    validation_data=val_tf_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print(f"\n{'='*80}")
print("✅ Fine-tuning complete!")
print(f"{'='*80}")


# ========================================
# PLOT TRAINING HISTORY
# ========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')

plt.title('CodeT5 Fine-tuning on MBPP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"📊 Training complete!")
print(f"  Final training loss: {history.history['loss'][-1]:.4f}")
print(f"  Final validation loss: {history.history['val_loss'][-1]:.4f}")
print(f"  Best validation loss: {min(history.history['val_loss']):.4f}")

# ========================================
# COMPUTE WEIGHT CHANGES PER VARIABLE
# ========================================

weight_changes = {}
for v in model.trainable_variables:
    initial = initial_weights[v.name]
    final = v.numpy()
    relative_change = np.linalg.norm(final - initial) / (np.linalg.norm(initial) + 1e-8)
    weight_changes[v.name] = relative_change

changes = list(weight_changes.values())
print(f"Weight change summary across {len(changes)} trainable variables:")
print(f"  Mean relative change : {np.mean(changes):.4f}")
print(f"  Median relative change: {np.median(changes):.4f}")
print(f"  Max relative change  : {np.max(changes):.4f}")
print(f"  Min relative change  : {np.min(changes):.4f}")


# ========================================
# VISUALISE: TOP 20 MOST-CHANGED LAYERS
# ========================================

layer_changes = sorted(weight_changes.items(), key=lambda x: x[1], reverse=True)

# Shorten variable names for readability
names = [n.split('/')[-2] + '/' + n.split('/')[-1] for n, _ in layer_changes[:20]]
values = [v for _, v in layer_changes[:20]]

plt.figure(figsize=(12, 6))
bars = plt.barh(names[::-1], values[::-1], color='steelblue', edgecolor='black', alpha=0.7)
plt.xlabel('Relative Weight Change (||Δw|| / ||w₀||)', fontsize=12)
plt.title('Top 20 Most-Changed Variables After Fine-tuning\n(smaller = pretrained knowledge better preserved)', fontsize=13)
plt.axvline(x=0.1, color='red', linestyle='--', label='0.1 threshold')
plt.legend()
plt.tight_layout()
plt.show()

print("✅ Weight change analysis complete")
print("A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.")

# ========================================
# DEFINE GENERATION FUNCTION
# ========================================

def generate_code(prompt, max_length=256, num_beams=5):
    """
    Generate code from a natural language prompt using CodeT5.

    Args:
        prompt: Natural language description of the task
        max_length: Maximum length of generated code
        num_beams: Number of beams for beam search (higher = better but slower)

    Returns:
        Generated code as a string
    """
    # Tokenize input
    inputs = tokenizer(
        prompt,
        return_tensors="tf",
        truncation=True,
        max_length=128
    )

    # Generate with beam search
    outputs = model.generate(
        inputs['input_ids'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True,
        no_repeat_ngram_size=2,  # Prevent repetition
    )

    # Decode generated tokens
    generated_code = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_code

print("✅ Generation function defined")



# ========================================
# TEST FINE-TUNED MODEL ON SAMPLES
# ========================================

print("🧪 Testing fine-tuned model on MBPP test examples...")
print("=" * 80)

# Test on first 3 test examples
num_samples = 3

for i in range(num_samples):
    print(f"\n{'='*80}")
    print(f"Example {i+1}/{num_samples}")
    print(f"{'='*80}")

    prompt = test_prompts[i]
    expected_code = test_code[i]

    print(f"\n📝 Prompt:")
    print(prompt[:200] + ("..." if len(prompt) > 200 else ""))

    print(f"\n🎯 Expected code:")
    print(expected_code[:300] + ("..." if len(expected_code) > 300 else ""))

    print(f"\n🤖 Generated code (fine-tuned):")
    generated = generate_code(prompt, max_length=256, num_beams=5)
    print(generated[:300] + ("..." if len(generated) > 300 else ""))
    print()

print(f"{'='*80}")
print("✅ Fine-tuned evaluation complete!")



# ========================================
# FINE-TUNED BLEU EVALUATION
# ========================================

# Load BLEU metric
bleu_metric = evaluate.load("bleu")

# Apply Python hints to test prompts (same as Parts A and B)
test_prompts_python = [add_python_hint(p) for p in test_prompts]

print("⚡ Generating all test codes in batches (greedy decoding for speed)...")
finetuned_generated = batch_generate_codes(  # --- EXPERIMENT HERE: batch_size, max_length, num_beams ---
    test_prompts_python,
    model=model,
    tokenizer=tokenizer,
)

# Score pre-generated codes (no inference needed — fast)
finetuned_bleu_scores, finetuned_syntax_valid, finetuned_codes, finetuned_stats = evaluate_model_with_bleu(
    test_prompts_python,
    test_code,
    None,  # generate_fn not needed — using pre-generated codes
    bleu_metric,
    model_label="Fine-Tuned CodeT5+",
    generated_codes=finetuned_generated,
)

# Analyze results with visualizations
analyze_bleu_results(
    finetuned_bleu_scores,
    finetuned_syntax_valid,
    finetuned_codes,
    test_prompts_python,
    test_code,
    finetuned_stats,
    model_label="Fine-Tuned CodeT5+"
)

# ========================================
# THREE-WAY COMPARISON
# ========================================

import pandas as pd

# Create comparison table
comparison_data = {
    'Model': ['Part A\n(From Scratch)', 'Part B\n(Zero-Shot)', 'Part C\n(Fine-Tuned)'],
    'BLEU (mean)': [0.96, PART_B_ZEROSHOT_BLEU_MEAN, finetuned_stats['mean']],
    'BLEU (min-max)': [
        f"0.00-2.99",
        f"{PART_B_ZEROSHOT_BLEU_MIN:.2f}-{PART_B_ZEROSHOT_BLEU_MAX:.2f}",
        f"{finetuned_stats['min']:.2f}-{finetuned_stats['max']:.2f}"
    ],
    'Syntax Valid (%)': [
        0.0,
        PART_B_ZEROSHOT_SYNTAX_PCT,
        finetuned_stats['syntax_valid_pct']
    ],
    'Model Size': [
        '~1M params',
        '220M params',
        '220M params'
    ],
    'Training Data': [
        '374 MBPP',
        'Large-scale code',
        'Large-scale + 374 MBPP'
    ]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 100)
print("📊 THREE-WAY MODEL COMPARISON")
print("=" * 100)
print(comparison_df.to_string(index=False))
print("=" * 100)

# Calculate improvement factors
improvement_zeroshot = PART_B_ZEROSHOT_BLEU_MEAN / 0.96 if 0.96 > 0 and PART_B_ZEROSHOT_BLEU_MEAN > 0 else 0
improvement_finetuned = finetuned_stats['mean'] / 0.96 if 0.96 > 0 else float('inf')
improvement_ft_vs_zs = finetuned_stats['mean'] / PART_B_ZEROSHOT_BLEU_MEAN if PART_B_ZEROSHOT_BLEU_MEAN > 0 else float('inf')

print(f"\n📈 Improvement Factors:")
print(f"  Zero-shot vs From-scratch: {improvement_zeroshot:.1f}x BLEU improvement")
print(f"  Fine-tuned vs From-scratch: {improvement_finetuned:.1f}x BLEU improvement")
print(f"  Fine-tuned vs Zero-shot: {improvement_ft_vs_zs:.1f}x BLEU improvement")

# Create comparison visualizations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Chart 1: Mean BLEU Comparison
models = comparison_df['Model']
bleu_means = comparison_df['BLEU (mean)']
colors = ['#e74c3c', '#f39c12', '#2ecc71']

bars = axes[0].bar(range(len(models)), bleu_means, color=colors, alpha=0.7, edgecolor='black')
axes[0].set_xticks(range(len(models)))
axes[0].set_xticklabels(models, fontsize=10)
axes[0].set_ylabel('BLEU Score (mean)', fontsize=12)
axes[0].set_title('BLEU Score Comparison', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')
axes[0].set_ylim(0, max(bleu_means) * 1.15 if max(bleu_means) > 0 else 10)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, bleu_means)):
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2., height + max(bleu_means)*0.02,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')

# Chart 2: Syntax Validity Comparison
syntax_pcts = comparison_df['Syntax Valid (%)']

bars = axes[1].bar(range(len(models)), syntax_pcts, color=colors, alpha=0.7, edgecolor='black')
axes[1].set_xticks(range(len(models)))
axes[1].set_xticklabels(models, fontsize=10)
axes[1].set_ylabel('Syntax Validity (%)', fontsize=12)
axes[1].set_title('Syntax Validity Comparison', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')
axes[1].set_ylim(0, 105)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, syntax_pcts)):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 2,
                f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

# Chart 3: BLEU Distribution Comparison
# Note: We don't have Part B distribution, so we'll show Part A vs Part C
axes[2].hist([0.96] * 50, bins=20, alpha=0.4, label='Part A (From Scratch)', color='#e74c3c', edgecolor='black')
axes[2].hist(finetuned_bleu_scores, bins=20, alpha=0.6, label='Part C (Fine-Tuned)', color='#2ecc71', edgecolor='black')
axes[2].set_xlabel('BLEU Score', fontsize=12)
axes[2].set_ylabel('Frequency', fontsize=12)
axes[2].set_title('BLEU Score Distributions', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=10)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Three-way comparison complete!")
# Out:
# Loading pretrained model: Salesforce/codet5-base
# Note: CodeT5+ is an improved version of CodeT5 with better pretraining
# This may take a few minutes on first run (downloads ~250MB)...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# TensorFlow weights not available, trying PyTorch conversion...
# Note: This requires PyTorch to be installed
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFT5ForConditionalGeneration: ['lm_head.weight', 'decoder.embed_tokens.weight', 'encoder.embed_tokens.weight']
# - This IS expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ✅ Model and tokenizer loaded!
# Model type: TFT5ForConditionalGeneration
# Tokenizer vocab size: 32,100
# Model parameters: ~220M
# Sample prompt:
# Write a function to find the longest chain which can be formed from the given set of pairs....
#
# Sample code:
# class Pair(object):
# 	def __init__(self, a, b):
# 		self.a = a
# 		self.b = b
# def max_chain_length(arr, n):
# 	max = 0
# 	mcl = [1 for i in range(n)...
#
# Tokenized input shape: (1, 21)
# Tokenized target shape: (1, 191)
#
# First 20 input tokens: [    1  3067   279   445   358  1104   326 12163  2687  1492   848   506
#  20010   628   326   864   444   434  5574    18]
# Decoded back: <s>Write a function to find the longest chain which can be formed from the given set of pairs.
# Tokenization configuration:
#   Max input length: 128
#   Max target length: 128
#   Batch size: 4
# ✅ Tokenization function defined
# 🔄 Tokenizing all datasets...
# ============================================================
# ✅ Training data tokenized (374 examples)
#    Input shape: (374, 128)
#    Labels shape: (374, 128)
# ✅ Validation data tokenized (90 examples)
#    Input shape: (90, 128)
#    Labels shape: (90, 128)
# ✅ Test data tokenized (50 examples)
#    Input shape: (50, 128)
#    Labels shape: (50, 128)
#
# ============================================================
# 🔄 Creating TensorFlow datasets for training...
# ✅ TensorFlow datasets created
#   Training batches: 94
#   Validation batches: 23
# ============================================================
# Training configuration:
#   Learning rate: 0.005
#   Epochs: 10
#   Warmup steps: 100
#   Dataset: MBPP
#   Training examples: 374
#   Validation examples: 90
# Compiling model...
# ✅ Model compiled successfully
# ✅ Captured initial weights for 257 trainable variables
# ✅ Callbacks configured
#   Model will be saved to: codet5_finetuned_mbpp.keras
#
# ================================================================================
# 🚀 Starting fine-tuning on MBPP dataset...
# ================================================================================
#
# Epoch 1/10
# 94/94 [==============================] - ETA: 0s - loss: 6.1309
# Epoch 1: val_loss improved from inf to 4.89257, saving model to codet5_finetuned_mbpp.keras
# /usr/local/lib/python3.12/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# 94/94 [==============================] - 334s 3s/step - loss: 6.1309 - val_loss: 4.8926
# Epoch 2/10
# 94/94 [==============================] - ETA: 0s - loss: 4.2241
# Epoch 2: val_loss improved from 4.89257 to 3.92307, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 267s 3s/step - loss: 4.2241 - val_loss: 3.9231
# Epoch 3/10
# 94/94 [==============================] - ETA: 0s - loss: 3.7121
# Epoch 3: val_loss improved from 3.92307 to 3.76072, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 287s 3s/step - loss: 3.7121 - val_loss: 3.7607
# Epoch 4/10
# 94/94 [==============================] - ETA: 0s - loss: 3.4889
# Epoch 4: val_loss improved from 3.76072 to 3.63013, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 296s 3s/step - loss: 3.4889 - val_loss: 3.6301
# Epoch 5/10
# 94/94 [==============================] - ETA: 0s - loss: 3.3895
# Epoch 5: val_loss improved from 3.63013 to 3.61978, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 303s 3s/step - loss: 3.3895 - val_loss: 3.6198
# Epoch 6/10
# 94/94 [==============================] - ETA: 0s - loss: 3.4232
# Epoch 6: val_loss improved from 3.61978 to 3.61712, saving model to codet5_finetuned_mbpp.keras
# 94/94 [==============================] - 295s 3s/step - loss: 3.4232 - val_loss: 3.6171
# Epoch 7/10
# 94/94 [==============================] - ETA: 0s - loss: 3.5936
# Epoch 7: val_loss did not improve from 3.61712
# 94/94 [==============================] - 33s 354ms/step - loss: 3.5936 - val_loss: 3.8564
# Epoch 8/10
# 94/94 [==============================] - ETA: 0s - loss: 3.7808
# Epoch 8: val_loss did not improve from 3.61712
# 94/94 [==============================] - 32s 343ms/step - loss: 3.7808 - val_loss: 3.9483
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# ================================================================================
# ✅ Fine-tuning complete!
# ================================================================================
# 📊 Training complete!
#   Final training loss: 3.7808
#   Final validation loss: 3.9483
#   Best validation loss: 3.6171
# Weight change summary across 257 trainable variables:
#   Mean relative change : 0.6688
#   Median relative change: 0.5431
#   Max relative change  : 3.0370
#   Min relative change  : 0.0162
# ✅ Weight change analysis complete
# A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.
# ✅ Generation function defined
# 🧪 Testing fine-tuned model on MBPP test examples...
# ================================================================================
#
# ================================================================================
# Example 1/3
# ================================================================================
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Expected code:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i in range(len(s) - 1,-1,-1):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     return s
#
# 🤖 Generated code (fine-tuned):
# def count_num(n):
#     if result
#
#
# ================================================================================
# Example 2/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Expected code:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated code (fine-tuned):
# def count_num(n):
#     if result
#
#
# ================================================================================
# Example 3/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Expected code:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four)
#
#
# 🤖 Generated code (fine-tuned):
# def count_num(n):
#     if result
#
# ================================================================================
# ✅ Fine-tuned evaluation complete!
# ⚡ Generating all test codes in batches (greedy decoding for speed)...
# Batch generation: 100%|██████████| 7/7 [00:49<00:00,  7.08s/it]
# 🔬 Scoring FINE-TUNED CODET5+ on 50 test examples (pre-generated)...
# ================================================================================
# Fine-Tuned CodeT5+ BLEU Evaluation: 100%|██████████| 50/50 [00:00<00:00, 140.97it/s]
# ================================================================================
# 📊 FINE-TUNED CODET5+ EVALUATION RESULTS
# ================================================================================
# BLEU Score (mean):        1.95
# BLEU Score (median):      0.00
# BLEU Score (std dev):     5.22
# BLEU Score (min):         0.00
# BLEU Score (max):         23.76
# Syntax Validity:          50/50 (100.0%)
# ================================================================================
#
# ✅ Fine-Tuned CodeT5+ evaluation complete!
#
# ================================================================================
# 📊 DETAILED ANALYSIS: FINE-TUNED CODET5+
# ================================================================================
# ================================================================================
# 🏆 BEST FINE-TUNED CODET5+ EXAMPLES (Highest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 - Example 25
# ================================================================================
# BLEU Score: 23.76
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to find the n-th rectangular number.
#
# 🎯 Reference:
# def find_rect_num(n):
#   return n*(n + 1)
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def count_Sum(n):
#     return (0,n)
#
# ================================================================================
# Rank #2 - Example 49
# ================================================================================
# BLEU Score: 22.47
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to find the nth octagonal number.
#
# 🎯 Reference:
# def is_octagonal(n):
# 	return 3 * n * n - 2 * n
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def count_Sum(n):
#     return (0,n)
#
# ================================================================================
# Rank #3 - Example 48
# ================================================================================
# BLEU Score: 13.56
# Syntax Valid: True
#
# 📝 Prompt:
# Write a python function to check whether the given two integers have opposite sign or not.
#
# 🎯 Reference:
# def opposite_Signs(x,y):
#     return ((x ^ y) < 0);
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def count_Sum(n):
#     return (0,n)
#
# ================================================================================
# 💔 WORST FINE-TUNED CODET5+ EXAMPLES (Lowest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 from bottom - Example 1
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Reference:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i i...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def count_Sum(n):
#     return (0,n)
#
# ================================================================================
# Rank #2 from bottom - Example 2
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Reference:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def count_Sum(n):
#     return (0,n)
#
# ================================================================================
# Rank #3 from bottom - Example 3
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: True
#
# 📝 Prompt:
# Python:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Reference:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def count_Sum(n):
#     return (0,n)
#
# ================================================================================
# ✅ Fine-Tuned CodeT5+ analysis complete!
# ================================================================================
#
# ====================================================================================================
# 📊 THREE-WAY MODEL COMPARISON
# ====================================================================================================
#                  Model  BLEU (mean) BLEU (min-max)  Syntax Valid (%)  Model Size          Training Data
# Part A\n(From Scratch)     0.960000      0.00-2.99               0.0  ~1M params               374 MBPP
#    Part B\n(Zero-Shot)     4.240000     0.00-26.84              44.0 220M params       Large-scale code
#   Part C\n(Fine-Tuned)     1.953213     0.00-23.76             100.0 220M params Large-scale + 374 MBPP
# ====================================================================================================
#
# 📈 Improvement Factors:
#   Zero-shot vs From-scratch: 4.4x BLEU improvement
#   Fine-tuned vs From-scratch: 2.0x BLEU improvement
#   Fine-tuned vs Zero-shot: 0.5x BLEU improvement
# ✅ Three-way comparison complete!

# %% [markdown]
# # Model 5

# %%
# ========================================
# LOAD CODET5 MODEL AND TOKENIZER
# ========================================

MODEL_NAME = "Salesforce/codet5-small"  # --- EXPERIMENT HERE: try other models (codet5-base, codet5p-770m, etc.) ---

print(f"Loading pretrained model: {MODEL_NAME}")
print("Note: CodeT5+ is an improved version of CodeT5 with better pretraining")
print("This may take a few minutes on first run (downloads ~250MB)...")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Load pretrained model
# Try loading TensorFlow weights directly first (no PyTorch conversion needed)
try:
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
    print("✅ Loaded from TensorFlow weights")
except Exception as e:
    print(f"TensorFlow weights not available, trying PyTorch conversion...")
    print(f"Note: This requires PyTorch to be installed")
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME, from_pt=True)

print(f"\n✅ Model and tokenizer loaded!")
print(f"Model type: {type(model).__name__}")
print(f"Tokenizer vocab size: {tokenizer.vocab_size:,}")
print(f"Model parameters: ~220M")

# ========================================
# TEST TOKENIZER ON SAMPLE
# ========================================

# Get a sample from training data
sample_prompt = train_prompts[0]
sample_code = train_code[0]

print("Sample prompt:")
print(sample_prompt[:150] + "...")
print("\nSample code:")
print(sample_code[:150] + "...")

# Tokenize
inputs = tokenizer(sample_prompt, return_tensors="tf", truncation=True, max_length=128)
targets = tokenizer(sample_code, return_tensors="tf", truncation=True, max_length=256)

print(f"\nTokenized input shape: {inputs['input_ids'].shape}")
print(f"Tokenized target shape: {targets['input_ids'].shape}")
print(f"\nFirst 20 input tokens: {inputs['input_ids'][0, :20].numpy()}")
print(f"Decoded back: {tokenizer.decode(inputs['input_ids'][0, :20], skip_special_tokens=False)}")


# ========================================
# TOKENIZATION CONFIGURATION
# ========================================

# Sequence length limits
# --- EXPERIMENT HERE: sequence lengths and batch size ---
MAX_INPUT_LENGTH = 256   # Maximum length for problem descriptions
MAX_TARGET_LENGTH = 256  # Maximum length for code solutions
BATCH_SIZE = 8           # Number of examples per batch (small due to model size)

print(f"Tokenization configuration:")
print(f"  Max input length: {MAX_INPUT_LENGTH}")
print(f"  Max target length: {MAX_TARGET_LENGTH}")
print(f"  Batch size: {BATCH_SIZE}")

# ========================================
# TOKENIZE DATASETS
# ========================================

def tokenize_function(prompts, codes):
    """
    Tokenize prompts and codes for seq2seq training.

    Args:
        prompts: List of problem descriptions
        codes: List of code solutions

    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    # Tokenize inputs (prompts)
    model_inputs = tokenizer(
        prompts,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Tokenize targets (codes)
    # Use text_target for encoder-decoder models
    labels = tokenizer(
        codes,
        max_length=MAX_TARGET_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Replace padding token id's in labels with -100 so they're ignored in loss
    labels_ids = labels['input_ids']
    labels_ids[labels_ids == tokenizer.pad_token_id] = -100

    return {
        'input_ids': model_inputs['input_ids'],
        'attention_mask': model_inputs['attention_mask'],
        'labels': labels_ids
    }

print("✅ Tokenization function defined")


# ========================================
# TOKENIZE ALL DATA AND CREATE TF DATASETS
# ========================================

print("🔄 Tokenizing all datasets...")
print("=" * 60)

# Tokenize all three splits
train_dataset = tokenize_function(train_prompts, train_code)
print(f"✅ Training data tokenized ({len(train_prompts)} examples)")
print(f"   Input shape: {train_dataset['input_ids'].shape}")
print(f"   Labels shape: {train_dataset['labels'].shape}")

val_dataset = tokenize_function(val_prompts, val_code)
print(f"✅ Validation data tokenized ({len(val_prompts)} examples)")
print(f"   Input shape: {val_dataset['input_ids'].shape}")
print(f"   Labels shape: {val_dataset['labels'].shape}")

test_dataset = tokenize_function(test_prompts, test_code)
print(f"✅ Test data tokenized ({len(test_prompts)} examples)")
print(f"   Input shape: {test_dataset['input_ids'].shape}")
print(f"   Labels shape: {test_dataset['labels'].shape}")

print("\n" + "=" * 60)
print("🔄 Creating TensorFlow datasets for training...")

# Convert to TensorFlow datasets
# IMPORTANT: For seq2seq models, labels must be in the input dictionary
train_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': train_dataset['input_ids'],
    'attention_mask': train_dataset['attention_mask'],
    'labels': train_dataset['labels']
})

val_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': val_dataset['input_ids'],
    'attention_mask': val_dataset['attention_mask'],
    'labels': val_dataset['labels']
})

# Batch and shuffle
train_tf_dataset = train_tf_dataset.shuffle(1000).batch(BATCH_SIZE)
val_tf_dataset = val_tf_dataset.batch(BATCH_SIZE)

print(f"✅ TensorFlow datasets created")
print(f"  Training batches: {len(train_tf_dataset)}")
print(f"  Validation batches: {len(val_tf_dataset)}")
print("=" * 60)

# ========================================
# TRAINING CONFIGURATION
# ========================================

# --- EXPERIMENT HERE: learning rate, epochs, warmup ---
LEARNING_RATE = 5e-3  # Lower learning rate for fine-tuning
EPOCHS = 15            # Fewer epochs needed for fine-tuning
WARMUP_STEPS = 100    # Gradual learning rate warmup

print(f"Training configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Epochs: {EPOCHS}")
print(f"  Warmup steps: {WARMUP_STEPS}")
print(f"  Dataset: MBPP")
print(f"  Training examples: {len(train_prompts)}")
print(f"  Validation examples: {len(val_prompts)}")

# ========================================
# COMPILE MODEL
# ========================================

print("Compiling model...")

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# Compile model
# Note: No loss function needed - model computes it internally from labels
model.compile(optimizer=optimizer)

print("✅ Model compiled successfully")

# ========================================
# CAPTURE INITIAL WEIGHTS (before training)
# ========================================

# Save a snapshot of all trainable weights before fine-tuning
# We'll compare these against post-training weights to measure how much changed
initial_weights = {v.name: v.numpy().copy() for v in model.trainable_variables}

print(f"✅ Captured initial weights for {len(initial_weights)} trainable variables")


# ========================================
# SET UP CALLBACKS
# ========================================

# Early stopping: stop if validation loss doesn't improve
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)

# Model checkpoint: save best model
model_save_path = "codet5_finetuned_mbpp.keras"
checkpoint = keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stopping, checkpoint]

print(f"✅ Callbacks configured")
print(f"  Model will be saved to: {model_save_path}")

# ========================================
# TRAIN MODEL
# ========================================

print(f"\n{'='*80}")
print("🚀 Starting fine-tuning on MBPP dataset...")
print(f"{'='*80}\n")

history = model.fit(
    train_tf_dataset,
    validation_data=val_tf_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print(f"\n{'='*80}")
print("✅ Fine-tuning complete!")
print(f"{'='*80}")


# ========================================
# PLOT TRAINING HISTORY
# ========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')

plt.title('CodeT5 Fine-tuning on MBPP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"📊 Training complete!")
print(f"  Final training loss: {history.history['loss'][-1]:.4f}")
print(f"  Final validation loss: {history.history['val_loss'][-1]:.4f}")
print(f"  Best validation loss: {min(history.history['val_loss']):.4f}")

# ========================================
# COMPUTE WEIGHT CHANGES PER VARIABLE
# ========================================

weight_changes = {}
for v in model.trainable_variables:
    initial = initial_weights[v.name]
    final = v.numpy()
    relative_change = np.linalg.norm(final - initial) / (np.linalg.norm(initial) + 1e-8)
    weight_changes[v.name] = relative_change

changes = list(weight_changes.values())
print(f"Weight change summary across {len(changes)} trainable variables:")
print(f"  Mean relative change : {np.mean(changes):.4f}")
print(f"  Median relative change: {np.median(changes):.4f}")
print(f"  Max relative change  : {np.max(changes):.4f}")
print(f"  Min relative change  : {np.min(changes):.4f}")


# ========================================
# VISUALISE: TOP 20 MOST-CHANGED LAYERS
# ========================================

layer_changes = sorted(weight_changes.items(), key=lambda x: x[1], reverse=True)

# Shorten variable names for readability
names = [n.split('/')[-2] + '/' + n.split('/')[-1] for n, _ in layer_changes[:20]]
values = [v for _, v in layer_changes[:20]]

plt.figure(figsize=(12, 6))
bars = plt.barh(names[::-1], values[::-1], color='steelblue', edgecolor='black', alpha=0.7)
plt.xlabel('Relative Weight Change (||Δw|| / ||w₀||)', fontsize=12)
plt.title('Top 20 Most-Changed Variables After Fine-tuning\n(smaller = pretrained knowledge better preserved)', fontsize=13)
plt.axvline(x=0.1, color='red', linestyle='--', label='0.1 threshold')
plt.legend()
plt.tight_layout()
plt.show()

print("✅ Weight change analysis complete")
print("A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.")

# ========================================
# DEFINE GENERATION FUNCTION
# ========================================

def generate_code(prompt, max_length=256, num_beams=5):
    """
    Generate code from a natural language prompt using CodeT5.

    Args:
        prompt: Natural language description of the task
        max_length: Maximum length of generated code
        num_beams: Number of beams for beam search (higher = better but slower)

    Returns:
        Generated code as a string
    """
    # Tokenize input
    inputs = tokenizer(
        prompt,
        return_tensors="tf",
        truncation=True,
        max_length=128
    )

    # Generate with beam search
    outputs = model.generate(
        inputs['input_ids'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True,
        no_repeat_ngram_size=2,  # Prevent repetition
    )

    # Decode generated tokens
    generated_code = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_code

print("✅ Generation function defined")



# ========================================
# TEST FINE-TUNED MODEL ON SAMPLES
# ========================================

print("🧪 Testing fine-tuned model on MBPP test examples...")
print("=" * 80)

# Test on first 3 test examples
num_samples = 3

for i in range(num_samples):
    print(f"\n{'='*80}")
    print(f"Example {i+1}/{num_samples}")
    print(f"{'='*80}")

    prompt = test_prompts[i]
    expected_code = test_code[i]

    print(f"\n📝 Prompt:")
    print(prompt[:200] + ("..." if len(prompt) > 200 else ""))

    print(f"\n🎯 Expected code:")
    print(expected_code[:300] + ("..." if len(expected_code) > 300 else ""))

    print(f"\n🤖 Generated code (fine-tuned):")
    generated = generate_code(prompt, max_length=256, num_beams=5)
    print(generated[:300] + ("..." if len(generated) > 300 else ""))
    print()

print(f"{'='*80}")
print("✅ Fine-tuned evaluation complete!")



# ========================================
# FINE-TUNED BLEU EVALUATION
# ========================================

# Load BLEU metric
bleu_metric = evaluate.load("bleu")

# Apply Python hints to test prompts (same as Parts A and B)
test_prompts_python = [add_python_hint(p) for p in test_prompts]

print("⚡ Generating all test codes in batches (greedy decoding for speed)...")
finetuned_generated = batch_generate_codes(  # --- EXPERIMENT HERE: batch_size, max_length, num_beams ---
    test_prompts_python,
    model=model,
    tokenizer=tokenizer,
)

# Score pre-generated codes (no inference needed — fast)
finetuned_bleu_scores, finetuned_syntax_valid, finetuned_codes, finetuned_stats = evaluate_model_with_bleu(
    test_prompts_python,
    test_code,
    None,  # generate_fn not needed — using pre-generated codes
    bleu_metric,
    model_label="Fine-Tuned CodeT5+",
    generated_codes=finetuned_generated,
)

# Analyze results with visualizations
analyze_bleu_results(
    finetuned_bleu_scores,
    finetuned_syntax_valid,
    finetuned_codes,
    test_prompts_python,
    test_code,
    finetuned_stats,
    model_label="Fine-Tuned CodeT5+"
)

# ========================================
# THREE-WAY COMPARISON
# ========================================

import pandas as pd

# Create comparison table
comparison_data = {
    'Model': ['Part A\n(From Scratch)', 'Part B\n(Zero-Shot)', 'Part C\n(Fine-Tuned)'],
    'BLEU (mean)': [0.96, PART_B_ZEROSHOT_BLEU_MEAN, finetuned_stats['mean']],
    'BLEU (min-max)': [
        f"0.00-2.99",
        f"{PART_B_ZEROSHOT_BLEU_MIN:.2f}-{PART_B_ZEROSHOT_BLEU_MAX:.2f}",
        f"{finetuned_stats['min']:.2f}-{finetuned_stats['max']:.2f}"
    ],
    'Syntax Valid (%)': [
        0.0,
        PART_B_ZEROSHOT_SYNTAX_PCT,
        finetuned_stats['syntax_valid_pct']
    ],
    'Model Size': [
        '~1M params',
        '220M params',
        '220M params'
    ],
    'Training Data': [
        '374 MBPP',
        'Large-scale code',
        'Large-scale + 374 MBPP'
    ]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 100)
print("📊 THREE-WAY MODEL COMPARISON")
print("=" * 100)
print(comparison_df.to_string(index=False))
print("=" * 100)

# Calculate improvement factors
improvement_zeroshot = PART_B_ZEROSHOT_BLEU_MEAN / 0.96 if 0.96 > 0 and PART_B_ZEROSHOT_BLEU_MEAN > 0 else 0
improvement_finetuned = finetuned_stats['mean'] / 0.96 if 0.96 > 0 else float('inf')
improvement_ft_vs_zs = finetuned_stats['mean'] / PART_B_ZEROSHOT_BLEU_MEAN if PART_B_ZEROSHOT_BLEU_MEAN > 0 else float('inf')

print(f"\n📈 Improvement Factors:")
print(f"  Zero-shot vs From-scratch: {improvement_zeroshot:.1f}x BLEU improvement")
print(f"  Fine-tuned vs From-scratch: {improvement_finetuned:.1f}x BLEU improvement")
print(f"  Fine-tuned vs Zero-shot: {improvement_ft_vs_zs:.1f}x BLEU improvement")

# Create comparison visualizations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Chart 1: Mean BLEU Comparison
models = comparison_df['Model']
bleu_means = comparison_df['BLEU (mean)']
colors = ['#e74c3c', '#f39c12', '#2ecc71']

bars = axes[0].bar(range(len(models)), bleu_means, color=colors, alpha=0.7, edgecolor='black')
axes[0].set_xticks(range(len(models)))
axes[0].set_xticklabels(models, fontsize=10)
axes[0].set_ylabel('BLEU Score (mean)', fontsize=12)
axes[0].set_title('BLEU Score Comparison', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')
axes[0].set_ylim(0, max(bleu_means) * 1.15 if max(bleu_means) > 0 else 10)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, bleu_means)):
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2., height + max(bleu_means)*0.02,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')

# Chart 2: Syntax Validity Comparison
syntax_pcts = comparison_df['Syntax Valid (%)']

bars = axes[1].bar(range(len(models)), syntax_pcts, color=colors, alpha=0.7, edgecolor='black')
axes[1].set_xticks(range(len(models)))
axes[1].set_xticklabels(models, fontsize=10)
axes[1].set_ylabel('Syntax Validity (%)', fontsize=12)
axes[1].set_title('Syntax Validity Comparison', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')
axes[1].set_ylim(0, 105)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, syntax_pcts)):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 2,
                f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

# Chart 3: BLEU Distribution Comparison
# Note: We don't have Part B distribution, so we'll show Part A vs Part C
axes[2].hist([0.96] * 50, bins=20, alpha=0.4, label='Part A (From Scratch)', color='#e74c3c', edgecolor='black')
axes[2].hist(finetuned_bleu_scores, bins=20, alpha=0.6, label='Part C (Fine-Tuned)', color='#2ecc71', edgecolor='black')
axes[2].set_xlabel('BLEU Score', fontsize=12)
axes[2].set_ylabel('Frequency', fontsize=12)
axes[2].set_title('BLEU Score Distributions', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=10)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Three-way comparison complete!")
# Out:
# Loading pretrained model: Salesforce/codet5-small
# Note: CodeT5+ is an improved version of CodeT5 with better pretraining
# This may take a few minutes on first run (downloads ~250MB)...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# TensorFlow weights not available, trying PyTorch conversion...
# Note: This requires PyTorch to be installed
# pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFT5ForConditionalGeneration: ['lm_head.weight', 'decoder.embed_tokens.weight', 'encoder.embed_tokens.weight']
# - This IS expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ✅ Model and tokenizer loaded!
# Model type: TFT5ForConditionalGeneration
# Tokenizer vocab size: 32,100
# Model parameters: ~220M
# Sample prompt:
# Write a function to find the longest chain which can be formed from the given set of pairs....
#
# Sample code:
# class Pair(object):
# 	def __init__(self, a, b):
# 		self.a = a
# 		self.b = b
# def max_chain_length(arr, n):
# 	max = 0
# 	mcl = [1 for i in range(n)...
#
# Tokenized input shape: (1, 21)
# Tokenized target shape: (1, 191)
#
# First 20 input tokens: [    1  3067   279   445   358  1104   326 12163  2687  1492   848   506
#  20010   628   326   864   444   434  5574    18]
# Decoded back: <s>Write a function to find the longest chain which can be formed from the given set of pairs.
# Tokenization configuration:
#   Max input length: 256
#   Max target length: 256
#   Batch size: 8
# ✅ Tokenization function defined
# 🔄 Tokenizing all datasets...
# ============================================================
# ✅ Training data tokenized (374 examples)
#    Input shape: (374, 256)
#    Labels shape: (374, 256)
# ✅ Validation data tokenized (90 examples)
#    Input shape: (90, 256)
#    Labels shape: (90, 256)
# ✅ Test data tokenized (50 examples)
#    Input shape: (50, 256)
#    Labels shape: (50, 256)
#
# ============================================================
# 🔄 Creating TensorFlow datasets for training...
# ✅ TensorFlow datasets created
#   Training batches: 47
#   Validation batches: 12
# ============================================================
# Training configuration:
#   Learning rate: 0.005
#   Epochs: 15
#   Warmup steps: 100
#   Dataset: MBPP
#   Training examples: 374
#   Validation examples: 90
# Compiling model...
# ✅ Model compiled successfully
# ✅ Captured initial weights for 131 trainable variables
# ✅ Callbacks configured
#   Model will be saved to: codet5_finetuned_mbpp.keras
#
# ================================================================================
# 🚀 Starting fine-tuning on MBPP dataset...
# ================================================================================
#
# Epoch 1/15
# 47/47 [==============================] - ETA: 0s - loss: 6.0428
# Epoch 1: val_loss improved from inf to 4.65171, saving model to codet5_finetuned_mbpp.keras
# /usr/local/lib/python3.12/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# 47/47 [==============================] - 85s 1s/step - loss: 6.0428 - val_loss: 4.6517
# Epoch 2/15
# 47/47 [==============================] - ETA: 0s - loss: 4.2339
# Epoch 2: val_loss improved from 4.65171 to 3.79531, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 50s 1s/step - loss: 4.2339 - val_loss: 3.7953
# Epoch 3/15
# 47/47 [==============================] - ETA: 0s - loss: 3.6655
# Epoch 3: val_loss improved from 3.79531 to 3.50036, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 53s 1s/step - loss: 3.6655 - val_loss: 3.5004
# Epoch 4/15
# 47/47 [==============================] - ETA: 0s - loss: 3.3779
# Epoch 4: val_loss improved from 3.50036 to 3.38615, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 24s 523ms/step - loss: 3.3779 - val_loss: 3.3861
# Epoch 5/15
# 47/47 [==============================] - ETA: 0s - loss: 3.2375
# Epoch 5: val_loss improved from 3.38615 to 3.32016, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 49s 1s/step - loss: 3.2375 - val_loss: 3.3202
# Epoch 6/15
# 47/47 [==============================] - ETA: 0s - loss: 3.1407
# Epoch 6: val_loss improved from 3.32016 to 3.30449, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 49s 1s/step - loss: 3.1407 - val_loss: 3.3045
# Epoch 7/15
# 47/47 [==============================] - ETA: 0s - loss: 3.0416
# Epoch 7: val_loss improved from 3.30449 to 3.24711, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 50s 1s/step - loss: 3.0416 - val_loss: 3.2471
# Epoch 8/15
# 47/47 [==============================] - ETA: 0s - loss: 2.9799
# Epoch 8: val_loss improved from 3.24711 to 3.21884, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 50s 1s/step - loss: 2.9799 - val_loss: 3.2188
# Epoch 9/15
# 47/47 [==============================] - ETA: 0s - loss: 2.9748
# Epoch 9: val_loss did not improve from 3.21884
# 47/47 [==============================] - 19s 403ms/step - loss: 2.9748 - val_loss: 3.3114
# Epoch 10/15
# 47/47 [==============================] - ETA: 0s - loss: 2.9867
# Epoch 10: val_loss did not improve from 3.21884
# 47/47 [==============================] - 19s 400ms/step - loss: 2.9867 - val_loss: 3.3611
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
# ================================================================================
# ✅ Fine-tuning complete!
# ================================================================================
# 📊 Training complete!
#   Final training loss: 2.9867
#   Final validation loss: 3.3611
#   Best validation loss: 3.2188
# Weight change summary across 131 trainable variables:
#   Mean relative change : 0.5139
#   Median relative change: 0.5088
#   Max relative change  : 2.0584
#   Min relative change  : 0.0161
# ✅ Weight change analysis complete
# A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.
# ✅ Generation function defined
# 🧪 Testing fine-tuned model on MBPP test examples...
# ================================================================================
#
# ================================================================================
# Example 1/3
# ================================================================================
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Expected code:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i in range(len(s) - 1,-1,-1):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     return s
#
# 🤖 Generated code (fine-tuned):
# import re
# def check_tuple(text_t,b):
#     if (res)
#
#
# ================================================================================
# Example 2/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Expected code:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated code (fine-tuned):
# def check_list(test_tup):
#     for i = [1, nums2, b in range(str_str(n):
#         if (res)
#
#
# ================================================================================
# Example 3/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Expected code:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four)
#
#
# 🤖 Generated code (fine-tuned):
# import re
# def check_tuple(text_t,b):
#     if (res)
#
# ================================================================================
# ✅ Fine-tuned evaluation complete!
# ⚡ Generating all test codes in batches (greedy decoding for speed)...
# Batch generation: 100%|██████████| 7/7 [02:13<00:00, 19.11s/it]
# 🔬 Scoring FINE-TUNED CODET5+ on 50 test examples (pre-generated)...
# ================================================================================
# Fine-Tuned CodeT5+ BLEU Evaluation: 100%|██████████| 50/50 [00:00<00:00, 130.01it/s]
# ================================================================================
# 📊 FINE-TUNED CODET5+ EVALUATION RESULTS
# ================================================================================
# BLEU Score (mean):        0.83
# BLEU Score (median):      0.00
# BLEU Score (std dev):     2.76
# BLEU Score (min):         0.00
# BLEU Score (max):         11.82
# Syntax Validity:          0/50 (0.0%)
# ================================================================================
#
# ✅ Fine-Tuned CodeT5+ evaluation complete!
#
# ================================================================================
# 📊 DETAILED ANALYSIS: FINE-TUNED CODET5+
# ================================================================================
# ================================================================================
# 🏆 BEST FINE-TUNED CODET5+ EXAMPLES (Highest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 - Example 6
# ================================================================================
# BLEU Score: 11.82
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to find sequences of lowercase letters joined with an underscore.
#
# 🎯 Reference:
# import re
# def text_lowercase_underscore(text):
#         patterns = '^[a-z]+_[a-z]+$'
#         if re.search(patterns,  text):
#                 return ...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_match_number(text):
#     if re.search(search('Notmatch(sub(patterns.text.sub('", text.find_str(find.patterns(string(pattern.string.pattern =...
#
# ================================================================================
# Rank #2 - Example 34
# ================================================================================
# BLEU Score: 11.20
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function that matches a word at the beginning of a string.
#
# 🎯 Reference:
# import re
# def text_match_string(text):
#         patterns = '^\w+'
#         if re.search(patterns,  text):
#                 return 'Found a match!'
#  ...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_match_number(text):
#  matched!'.search(search('Not matched
#
# ================================================================================
# Rank #3 - Example 33
# ================================================================================
# BLEU Score: 10.17
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to find sequences of lowercase letters joined with an underscore using regex.
#
# 🎯 Reference:
# import re
# def text_match(text):
#   patterns = '^[a-z]+_[a-z]+$'
#   if re.search(patterns,  text):
#     return ('Found a match!')
#   else:
#     return...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_match_number(text):
#     if re.search(search('Notmatch(sub(patterns.text.sub('", text.find_str(find.patterns(string(pattern.string.pattern =...
#
# ================================================================================
# 💔 WORST FINE-TUNED CODET5+ EXAMPLES (Lowest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 from bottom - Example 2
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Reference:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_tuple(test_tup):
#  matched
#
# ================================================================================
# Rank #2 from bottom - Example 3
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Reference:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_tuple(text):
#  matched
#
# ================================================================================
# Rank #3 from bottom - Example 4
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Write a python function to find the volume of a triangular prism.
#
# 🎯 Reference:
# def find_Volume(l,b,h) :
#     return ((l * b * h) / 2)
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def check_tuple(test_tup):
#  matched
#
# ================================================================================
# ✅ Fine-Tuned CodeT5+ analysis complete!
# ================================================================================
#
# ====================================================================================================
# 📊 THREE-WAY MODEL COMPARISON
# ====================================================================================================
#                  Model  BLEU (mean) BLEU (min-max)  Syntax Valid (%)  Model Size          Training Data
# Part A\n(From Scratch)     0.960000      0.00-2.99               0.0  ~1M params               374 MBPP
#    Part B\n(Zero-Shot)     4.240000     0.00-26.84              44.0 220M params       Large-scale code
#   Part C\n(Fine-Tuned)     0.829701     0.00-11.82               0.0 220M params Large-scale + 374 MBPP
# ====================================================================================================
#
# 📈 Improvement Factors:
#   Zero-shot vs From-scratch: 4.4x BLEU improvement
#   Fine-tuned vs From-scratch: 0.9x BLEU improvement
#   Fine-tuned vs Zero-shot: 0.2x BLEU improvement
# ✅ Three-way comparison complete!

# %% [markdown]
# # Model 6

# %%
# ========================================
# LOAD CODET5 MODEL AND TOKENIZER
# ========================================

MODEL_NAME = "Salesforce/codet5-small"  # --- EXPERIMENT HERE: try other models (codet5-base, codet5p-770m, etc.) ---

print(f"Loading pretrained model: {MODEL_NAME}")
print("Note: CodeT5+ is an improved version of CodeT5 with better pretraining")
print("This may take a few minutes on first run (downloads ~250MB)...")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Load pretrained model
# Try loading TensorFlow weights directly first (no PyTorch conversion needed)
try:
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)
    print("✅ Loaded from TensorFlow weights")
except Exception as e:
    print(f"TensorFlow weights not available, trying PyTorch conversion...")
    print(f"Note: This requires PyTorch to be installed")
    model = TFAutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME, from_pt=True)

print(f"\n✅ Model and tokenizer loaded!")
print(f"Model type: {type(model).__name__}")
print(f"Tokenizer vocab size: {tokenizer.vocab_size:,}")
print(f"Model parameters: ~220M")

# ========================================
# TEST TOKENIZER ON SAMPLE
# ========================================

# Get a sample from training data
sample_prompt = train_prompts[0]
sample_code = train_code[0]

print("Sample prompt:")
print(sample_prompt[:150] + "...")
print("\nSample code:")
print(sample_code[:150] + "...")

# Tokenize
inputs = tokenizer(sample_prompt, return_tensors="tf", truncation=True, max_length=128)
targets = tokenizer(sample_code, return_tensors="tf", truncation=True, max_length=256)

print(f"\nTokenized input shape: {inputs['input_ids'].shape}")
print(f"Tokenized target shape: {targets['input_ids'].shape}")
print(f"\nFirst 20 input tokens: {inputs['input_ids'][0, :20].numpy()}")
print(f"Decoded back: {tokenizer.decode(inputs['input_ids'][0, :20], skip_special_tokens=False)}")


# ========================================
# TOKENIZATION CONFIGURATION
# ========================================

# Sequence length limits
# --- EXPERIMENT HERE: sequence lengths and batch size ---
MAX_INPUT_LENGTH = 256   # Maximum length for problem descriptions
MAX_TARGET_LENGTH = 512  # Maximum length for code solutions
BATCH_SIZE = 8           # Number of examples per batch (small due to model size)

print(f"Tokenization configuration:")
print(f"  Max input length: {MAX_INPUT_LENGTH}")
print(f"  Max target length: {MAX_TARGET_LENGTH}")
print(f"  Batch size: {BATCH_SIZE}")

# ========================================
# TOKENIZE DATASETS
# ========================================

def tokenize_function(prompts, codes):
    """
    Tokenize prompts and codes for seq2seq training.

    Args:
        prompts: List of problem descriptions
        codes: List of code solutions

    Returns:
        Dictionary with input_ids, attention_mask, and labels
    """
    # Tokenize inputs (prompts)
    model_inputs = tokenizer(
        prompts,
        max_length=MAX_INPUT_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Tokenize targets (codes)
    # Use text_target for encoder-decoder models
    labels = tokenizer(
        codes,
        max_length=MAX_TARGET_LENGTH,
        truncation=True,
        padding='max_length',
        return_tensors='np'
    )

    # Replace padding token id's in labels with -100 so they're ignored in loss
    labels_ids = labels['input_ids']
    labels_ids[labels_ids == tokenizer.pad_token_id] = -100

    return {
        'input_ids': model_inputs['input_ids'],
        'attention_mask': model_inputs['attention_mask'],
        'labels': labels_ids
    }

print("✅ Tokenization function defined")


# ========================================
# TOKENIZE ALL DATA AND CREATE TF DATASETS
# ========================================

print("🔄 Tokenizing all datasets...")
print("=" * 60)

# Tokenize all three splits
train_dataset = tokenize_function(train_prompts, train_code)
print(f"✅ Training data tokenized ({len(train_prompts)} examples)")
print(f"   Input shape: {train_dataset['input_ids'].shape}")
print(f"   Labels shape: {train_dataset['labels'].shape}")

val_dataset = tokenize_function(val_prompts, val_code)
print(f"✅ Validation data tokenized ({len(val_prompts)} examples)")
print(f"   Input shape: {val_dataset['input_ids'].shape}")
print(f"   Labels shape: {val_dataset['labels'].shape}")

test_dataset = tokenize_function(test_prompts, test_code)
print(f"✅ Test data tokenized ({len(test_prompts)} examples)")
print(f"   Input shape: {test_dataset['input_ids'].shape}")
print(f"   Labels shape: {test_dataset['labels'].shape}")

print("\n" + "=" * 60)
print("🔄 Creating TensorFlow datasets for training...")

# Convert to TensorFlow datasets
# IMPORTANT: For seq2seq models, labels must be in the input dictionary
train_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': train_dataset['input_ids'],
    'attention_mask': train_dataset['attention_mask'],
    'labels': train_dataset['labels']
})

val_tf_dataset = tf.data.Dataset.from_tensor_slices({
    'input_ids': val_dataset['input_ids'],
    'attention_mask': val_dataset['attention_mask'],
    'labels': val_dataset['labels']
})

# Batch and shuffle
train_tf_dataset = train_tf_dataset.shuffle(1000).batch(BATCH_SIZE)
val_tf_dataset = val_tf_dataset.batch(BATCH_SIZE)

print(f"✅ TensorFlow datasets created")
print(f"  Training batches: {len(train_tf_dataset)}")
print(f"  Validation batches: {len(val_tf_dataset)}")
print("=" * 60)

# ========================================
# TRAINING CONFIGURATION
# ========================================

# --- EXPERIMENT HERE: learning rate, epochs, warmup ---
LEARNING_RATE = 5e-5  # Lower learning rate for fine-tuning
EPOCHS = 5            # Fewer epochs needed for fine-tuning
WARMUP_STEPS = 100    # Gradual learning rate warmup

print(f"Training configuration:")
print(f"  Learning rate: {LEARNING_RATE}")
print(f"  Epochs: {EPOCHS}")
print(f"  Warmup steps: {WARMUP_STEPS}")
print(f"  Dataset: MBPP")
print(f"  Training examples: {len(train_prompts)}")
print(f"  Validation examples: {len(val_prompts)}")

# ========================================
# COMPILE MODEL
# ========================================

print("Compiling model...")

# Set up optimizer
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# Compile model
# Note: No loss function needed - model computes it internally from labels
model.compile(optimizer=optimizer)

print("✅ Model compiled successfully")

# ========================================
# CAPTURE INITIAL WEIGHTS (before training)
# ========================================

# Save a snapshot of all trainable weights before fine-tuning
# We'll compare these against post-training weights to measure how much changed
initial_weights = {v.name: v.numpy().copy() for v in model.trainable_variables}

print(f"✅ Captured initial weights for {len(initial_weights)} trainable variables")


# ========================================
# SET UP CALLBACKS
# ========================================

# Early stopping: stop if validation loss doesn't improve
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)

# Model checkpoint: save best model
model_save_path = "codet5_finetuned_mbpp.keras"
checkpoint = keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stopping, checkpoint]

print(f"✅ Callbacks configured")
print(f"  Model will be saved to: {model_save_path}")

# ========================================
# TRAIN MODEL
# ========================================

print(f"\n{'='*80}")
print("🚀 Starting fine-tuning on MBPP dataset...")
print(f"{'='*80}\n")

history = model.fit(
    train_tf_dataset,
    validation_data=val_tf_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print(f"\n{'='*80}")
print("✅ Fine-tuning complete!")
print(f"{'='*80}")


# ========================================
# PLOT TRAINING HISTORY
# ========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')

plt.title('CodeT5 Fine-tuning on MBPP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print(f"📊 Training complete!")
print(f"  Final training loss: {history.history['loss'][-1]:.4f}")
print(f"  Final validation loss: {history.history['val_loss'][-1]:.4f}")
print(f"  Best validation loss: {min(history.history['val_loss']):.4f}")

# ========================================
# COMPUTE WEIGHT CHANGES PER VARIABLE
# ========================================

weight_changes = {}
for v in model.trainable_variables:
    initial = initial_weights[v.name]
    final = v.numpy()
    relative_change = np.linalg.norm(final - initial) / (np.linalg.norm(initial) + 1e-8)
    weight_changes[v.name] = relative_change

changes = list(weight_changes.values())
print(f"Weight change summary across {len(changes)} trainable variables:")
print(f"  Mean relative change : {np.mean(changes):.4f}")
print(f"  Median relative change: {np.median(changes):.4f}")
print(f"  Max relative change  : {np.max(changes):.4f}")
print(f"  Min relative change  : {np.min(changes):.4f}")


# ========================================
# VISUALISE: TOP 20 MOST-CHANGED LAYERS
# ========================================

layer_changes = sorted(weight_changes.items(), key=lambda x: x[1], reverse=True)

# Shorten variable names for readability
names = [n.split('/')[-2] + '/' + n.split('/')[-1] for n, _ in layer_changes[:20]]
values = [v for _, v in layer_changes[:20]]

plt.figure(figsize=(12, 6))
bars = plt.barh(names[::-1], values[::-1], color='steelblue', edgecolor='black', alpha=0.7)
plt.xlabel('Relative Weight Change (||Δw|| / ||w₀||)', fontsize=12)
plt.title('Top 20 Most-Changed Variables After Fine-tuning\n(smaller = pretrained knowledge better preserved)', fontsize=13)
plt.axvline(x=0.1, color='red', linestyle='--', label='0.1 threshold')
plt.legend()
plt.tight_layout()
plt.show()

print("✅ Weight change analysis complete")
print("A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.")

# ========================================
# DEFINE GENERATION FUNCTION
# ========================================

def generate_code(prompt, max_length=256, num_beams=5):
    """
    Generate code from a natural language prompt using CodeT5.

    Args:
        prompt: Natural language description of the task
        max_length: Maximum length of generated code
        num_beams: Number of beams for beam search (higher = better but slower)

    Returns:
        Generated code as a string
    """
    # Tokenize input
    inputs = tokenizer(
        prompt,
        return_tensors="tf",
        truncation=True,
        max_length=128
    )

    # Generate with beam search
    outputs = model.generate(
        inputs['input_ids'],
        max_length=max_length,
        num_beams=num_beams,
        early_stopping=True,
        no_repeat_ngram_size=2,  # Prevent repetition
    )

    # Decode generated tokens
    generated_code = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_code

print("✅ Generation function defined")



# ========================================
# TEST FINE-TUNED MODEL ON SAMPLES
# ========================================

print("🧪 Testing fine-tuned model on MBPP test examples...")
print("=" * 80)

# Test on first 3 test examples
num_samples = 3

for i in range(num_samples):
    print(f"\n{'='*80}")
    print(f"Example {i+1}/{num_samples}")
    print(f"{'='*80}")

    prompt = test_prompts[i]
    expected_code = test_code[i]

    print(f"\n📝 Prompt:")
    print(prompt[:200] + ("..." if len(prompt) > 200 else ""))

    print(f"\n🎯 Expected code:")
    print(expected_code[:300] + ("..." if len(expected_code) > 300 else ""))

    print(f"\n🤖 Generated code (fine-tuned):")
    generated = generate_code(prompt, max_length=256, num_beams=5)
    print(generated[:300] + ("..." if len(generated) > 300 else ""))
    print()

print(f"{'='*80}")
print("✅ Fine-tuned evaluation complete!")



# ========================================
# FINE-TUNED BLEU EVALUATION
# ========================================

# Load BLEU metric
bleu_metric = evaluate.load("bleu")

# Apply Python hints to test prompts (same as Parts A and B)
test_prompts_python = [add_python_hint(p) for p in test_prompts]

print("⚡ Generating all test codes in batches (greedy decoding for speed)...")
finetuned_generated = batch_generate_codes(  # --- EXPERIMENT HERE: batch_size, max_length, num_beams ---
    test_prompts_python,
    model=model,
    tokenizer=tokenizer,
)

# Score pre-generated codes (no inference needed — fast)
finetuned_bleu_scores, finetuned_syntax_valid, finetuned_codes, finetuned_stats = evaluate_model_with_bleu(
    test_prompts_python,
    test_code,
    None,  # generate_fn not needed — using pre-generated codes
    bleu_metric,
    model_label="Fine-Tuned CodeT5+",
    generated_codes=finetuned_generated,
)

# Analyze results with visualizations
analyze_bleu_results(
    finetuned_bleu_scores,
    finetuned_syntax_valid,
    finetuned_codes,
    test_prompts_python,
    test_code,
    finetuned_stats,
    model_label="Fine-Tuned CodeT5+"
)

# ========================================
# THREE-WAY COMPARISON
# ========================================

import pandas as pd

# Create comparison table
comparison_data = {
    'Model': ['Part A\n(From Scratch)', 'Part B\n(Zero-Shot)', 'Part C\n(Fine-Tuned)'],
    'BLEU (mean)': [0.96, PART_B_ZEROSHOT_BLEU_MEAN, finetuned_stats['mean']],
    'BLEU (min-max)': [
        f"0.00-2.99",
        f"{PART_B_ZEROSHOT_BLEU_MIN:.2f}-{PART_B_ZEROSHOT_BLEU_MAX:.2f}",
        f"{finetuned_stats['min']:.2f}-{finetuned_stats['max']:.2f}"
    ],
    'Syntax Valid (%)': [
        0.0,
        PART_B_ZEROSHOT_SYNTAX_PCT,
        finetuned_stats['syntax_valid_pct']
    ],
    'Model Size': [
        '~1M params',
        '220M params',
        '220M params'
    ],
    'Training Data': [
        '374 MBPP',
        'Large-scale code',
        'Large-scale + 374 MBPP'
    ]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 100)
print("📊 THREE-WAY MODEL COMPARISON")
print("=" * 100)
print(comparison_df.to_string(index=False))
print("=" * 100)

# Calculate improvement factors
improvement_zeroshot = PART_B_ZEROSHOT_BLEU_MEAN / 0.96 if 0.96 > 0 and PART_B_ZEROSHOT_BLEU_MEAN > 0 else 0
improvement_finetuned = finetuned_stats['mean'] / 0.96 if 0.96 > 0 else float('inf')
improvement_ft_vs_zs = finetuned_stats['mean'] / PART_B_ZEROSHOT_BLEU_MEAN if PART_B_ZEROSHOT_BLEU_MEAN > 0 else float('inf')

print(f"\n📈 Improvement Factors:")
print(f"  Zero-shot vs From-scratch: {improvement_zeroshot:.1f}x BLEU improvement")
print(f"  Fine-tuned vs From-scratch: {improvement_finetuned:.1f}x BLEU improvement")
print(f"  Fine-tuned vs Zero-shot: {improvement_ft_vs_zs:.1f}x BLEU improvement")

# Create comparison visualizations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Chart 1: Mean BLEU Comparison
models = comparison_df['Model']
bleu_means = comparison_df['BLEU (mean)']
colors = ['#e74c3c', '#f39c12', '#2ecc71']

bars = axes[0].bar(range(len(models)), bleu_means, color=colors, alpha=0.7, edgecolor='black')
axes[0].set_xticks(range(len(models)))
axes[0].set_xticklabels(models, fontsize=10)
axes[0].set_ylabel('BLEU Score (mean)', fontsize=12)
axes[0].set_title('BLEU Score Comparison', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3, axis='y')
axes[0].set_ylim(0, max(bleu_means) * 1.15 if max(bleu_means) > 0 else 10)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, bleu_means)):
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2., height + max(bleu_means)*0.02,
                f'{val:.2f}', ha='center', va='bottom', fontweight='bold')

# Chart 2: Syntax Validity Comparison
syntax_pcts = comparison_df['Syntax Valid (%)']

bars = axes[1].bar(range(len(models)), syntax_pcts, color=colors, alpha=0.7, edgecolor='black')
axes[1].set_xticks(range(len(models)))
axes[1].set_xticklabels(models, fontsize=10)
axes[1].set_ylabel('Syntax Validity (%)', fontsize=12)
axes[1].set_title('Syntax Validity Comparison', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3, axis='y')
axes[1].set_ylim(0, 105)

# Add value labels on bars
for i, (bar, val) in enumerate(zip(bars, syntax_pcts)):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 2,
                f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

# Chart 3: BLEU Distribution Comparison
# Note: We don't have Part B distribution, so we'll show Part A vs Part C
axes[2].hist([0.96] * 50, bins=20, alpha=0.4, label='Part A (From Scratch)', color='#e74c3c', edgecolor='black')
axes[2].hist(finetuned_bleu_scores, bins=20, alpha=0.6, label='Part C (Fine-Tuned)', color='#2ecc71', edgecolor='black')
axes[2].set_xlabel('BLEU Score', fontsize=12)
axes[2].set_ylabel('Frequency', fontsize=12)
axes[2].set_title('BLEU Score Distributions', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=10)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Three-way comparison complete!")
# Out:
# Loading pretrained model: Salesforce/codet5-small
# Note: CodeT5+ is an improved version of CodeT5 with better pretraining
# This may take a few minutes on first run (downloads ~250MB)...
# TensorFlow weights not available, trying PyTorch conversion...
# Note: This requires PyTorch to be installed
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFT5ForConditionalGeneration: ['lm_head.weight', 'decoder.embed_tokens.weight', 'encoder.embed_tokens.weight']
# - This IS expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5ForConditionalGeneration from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ✅ Model and tokenizer loaded!
# Model type: TFT5ForConditionalGeneration
# Tokenizer vocab size: 32,100
# Model parameters: ~220M
# Sample prompt:
# Write a function to find the longest chain which can be formed from the given set of pairs....
#
# Sample code:
# class Pair(object):
# 	def __init__(self, a, b):
# 		self.a = a
# 		self.b = b
# def max_chain_length(arr, n):
# 	max = 0
# 	mcl = [1 for i in range(n)...
#
# Tokenized input shape: (1, 21)
# Tokenized target shape: (1, 191)
#
# First 20 input tokens: [    1  3067   279   445   358  1104   326 12163  2687  1492   848   506
#  20010   628   326   864   444   434  5574    18]
# Decoded back: <s>Write a function to find the longest chain which can be formed from the given set of pairs.
# Tokenization configuration:
#   Max input length: 256
#   Max target length: 512
#   Batch size: 8
# ✅ Tokenization function defined
# 🔄 Tokenizing all datasets...
# ============================================================
# ✅ Training data tokenized (374 examples)
#    Input shape: (374, 256)
#    Labels shape: (374, 512)
# ✅ Validation data tokenized (90 examples)
#    Input shape: (90, 256)
#    Labels shape: (90, 512)
# ✅ Test data tokenized (50 examples)
#    Input shape: (50, 256)
#    Labels shape: (50, 512)
#
# ============================================================
# 🔄 Creating TensorFlow datasets for training...
# ✅ TensorFlow datasets created
#   Training batches: 47
#   Validation batches: 12
# ============================================================
# Training configuration:
#   Learning rate: 5e-05
#   Epochs: 5
#   Warmup steps: 100
#   Dataset: MBPP
#   Training examples: 374
#   Validation examples: 90
# Compiling model...
# ✅ Model compiled successfully
# ✅ Captured initial weights for 131 trainable variables
# ✅ Callbacks configured
#   Model will be saved to: codet5_finetuned_mbpp.keras
#
# ================================================================================
# 🚀 Starting fine-tuning on MBPP dataset...
# ================================================================================
#
# Epoch 1/5
# 47/47 [==============================] - ETA: 0s - loss: 4.2186
# Epoch 1: val_loss improved from inf to 2.46691, saving model to codet5_finetuned_mbpp.keras
# /usr/local/lib/python3.12/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# 47/47 [==============================] - 113s 2s/step - loss: 4.2186 - val_loss: 2.4669
# Epoch 2/5
# 47/47 [==============================] - ETA: 0s - loss: 2.4389
# Epoch 2: val_loss improved from 2.46691 to 1.99374, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 68s 1s/step - loss: 2.4389 - val_loss: 1.9937
# Epoch 3/5
# 47/47 [==============================] - ETA: 0s - loss: 2.0739
# Epoch 3: val_loss improved from 1.99374 to 1.80251, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 73s 2s/step - loss: 2.0739 - val_loss: 1.8025
# Epoch 4/5
# 47/47 [==============================] - ETA: 0s - loss: 1.8823
# Epoch 4: val_loss improved from 1.80251 to 1.70221, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 69s 1s/step - loss: 1.8823 - val_loss: 1.7022
# Epoch 5/5
# 47/47 [==============================] - ETA: 0s - loss: 1.7263
# Epoch 5: val_loss improved from 1.70221 to 1.63651, saving model to codet5_finetuned_mbpp.keras
# 47/47 [==============================] - 63s 1s/step - loss: 1.7263 - val_loss: 1.6365
# Restoring model weights from the end of the best epoch: 5.
#
# ================================================================================
# ✅ Fine-tuning complete!
# ================================================================================
# 📊 Training complete!
#   Final training loss: 1.7263
#   Final validation loss: 1.6365
#   Best validation loss: 1.6365
# Weight change summary across 131 trainable variables:
#   Mean relative change : 0.0115
#   Median relative change: 0.0113
#   Max relative change  : 0.0281
#   Min relative change  : 0.0002
# ✅ Weight change analysis complete
# A mean relative change well below 0.1 confirms the low LR preserved pretrained knowledge.
# ✅ Generation function defined
# 🧪 Testing fine-tuned model on MBPP test examples...
# ================================================================================
#
# ================================================================================
# Example 1/3
# ================================================================================
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Expected code:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i in range(len(s) - 1,-1,-1):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     return s
#
# 🤖 Generated code (fine-tuned):
# import re
# def remove_first_last_occurrence(str1):
#     result = re.findall(r'[A-Z]', str1, str2), re .sub('[a-z0-9_]+', r'\1',str2)  return result
#
#
# ================================================================================
# Example 2/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to sort a given matrix in ascending order according to the sum of its rows.
#
# 🎯 Expected code:
# def sort_matrix(M):
#     result = sorted(M, key=sum)
#     return result
#
# 🤖 Generated code (fine-tuned):
# def sort_matrix(matrix):
#   res = matrix.sum(key=lambda x, y: x + y, key = x)
#     return (res)
#
#
# ================================================================================
# Example 3/3
# ================================================================================
#
# 📝 Prompt:
# Write a function to count the most common words in a dictionary.
#
# 🎯 Expected code:
# from collections import Counter
# def count_common(words):
#   word_counts = Counter(words)
#   top_four = word_counts.most_common(4)
#   return (top_four)
#
#
# 🤖 Generated code (fine-tuned):
# def most_common_words(dict1):
#     result = Counter(map(int, dict1.keys()), dict2.values()))
#         return (result)
#
# ================================================================================
# ✅ Fine-tuned evaluation complete!
# ⚡ Generating all test codes in batches (greedy decoding for speed)...
# Batch generation: 100%|██████████| 7/7 [01:53<00:00, 16.28s/it]
# 🔬 Scoring FINE-TUNED CODET5+ on 50 test examples (pre-generated)...
# ================================================================================
# Fine-Tuned CodeT5+ BLEU Evaluation: 100%|██████████| 50/50 [00:00<00:00, 179.75it/s]
# ================================================================================
# 📊 FINE-TUNED CODET5+ EVALUATION RESULTS
# ================================================================================
# BLEU Score (mean):        5.61
# BLEU Score (median):      0.35
# BLEU Score (std dev):     7.49
# BLEU Score (min):         0.00
# BLEU Score (max):         33.10
# Syntax Validity:          7/50 (14.0%)
# ================================================================================
#
# ✅ Fine-Tuned CodeT5+ evaluation complete!
#
# ================================================================================
# 📊 DETAILED ANALYSIS: FINE-TUNED CODET5+
# ================================================================================
# ================================================================================
# 🏆 BEST FINE-TUNED CODET5+ EXAMPLES (Highest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 - Example 5
# ================================================================================
# BLEU Score: 33.10
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to split a string at lowercase letters.
#
# 🎯 Reference:
# import re
# def split_lowerstring(text):
#  return (re.findall('[a-z][^a-z]*', text))
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# import re
#  setDefinition
#     return re.sub('[A-Z]', text)
#
# ================================================================================
# Rank #2 - Example 32
# ================================================================================
# BLEU Score: 19.00
# Syntax Valid: False
#
# 📝 Prompt:
# Write a python function to find the sum of repeated elements in a given array.
#
# 🎯 Reference:
# def find_Sum(arr,n):
#     return sum([x for x in arr if arr.count(x) > 1])
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def sum_repeated(arr,n):
#     sum = 0
#         return sum
#
# ================================================================================
# Rank #3 - Example 31
# ================================================================================
# BLEU Score: 18.53
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to filter even numbers using lambda function.
#
# 🎯 Reference:
# def filter_evennumbers(nums):
#  even_nums = list(filter(lambda x: x%2 == 0, nums))
#  return even_nums
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def filter_even(n):
# Backend return result
#
# ================================================================================
# 💔 WORST FINE-TUNED CODET5+ EXAMPLES (Lowest BLEU)
# ================================================================================
#
# ================================================================================
# Rank #1 from bottom - Example 1
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Write a python function to remove first and last occurrence of a given character from the string.
#
# 🎯 Reference:
# def remove_Occ(s,ch):
#     for i in range(len(s)):
#         if (s[i] == ch):
#             s = s[0 : i] + s[i + 1:]
#             break
#     for i i...
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# import re
# LEMENT    if re.search(r'\w+', text):
# LEMENTLEMENT
#
# ================================================================================
# Rank #2 from bottom - Example 4
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Write a python function to find the volume of a triangular prism.
#
# 🎯 Reference:
# def find_Volume(l,b,h) :
#     return ((l * b * h) / 2)
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def triangular_prism_volume(n):
#     volume = 0
# Backend
#
# ================================================================================
# Rank #3 from bottom - Example 7
# ================================================================================
# BLEU Score: 0.00
# Syntax Valid: False
#
# 📝 Prompt:
# Python:
# Write a function to find the perimeter of a square.
#
# 🎯 Reference:
# def square_perimeter(a):
#   perimeter=4*a
#   return perimeter
#
# 🤖 Generated (Fine-Tuned CodeT5+):
# def perimeter(x,y):
# TemplateInstance        per-imeter[i] = per(per_area[j] - x) ...
#
# ================================================================================
# ✅ Fine-Tuned CodeT5+ analysis complete!
# ================================================================================
#
# ====================================================================================================
# 📊 THREE-WAY MODEL COMPARISON
# ====================================================================================================
#                  Model  BLEU (mean) BLEU (min-max)  Syntax Valid (%)  Model Size          Training Data
# Part A\n(From Scratch)     0.960000      0.00-2.99               0.0  ~1M params               374 MBPP
#    Part B\n(Zero-Shot)     4.240000     0.00-26.84              44.0 220M params       Large-scale code
#   Part C\n(Fine-Tuned)     5.609669     0.00-33.10              14.0 220M params Large-scale + 374 MBPP
# ====================================================================================================
#
# 📈 Improvement Factors:
#   Zero-shot vs From-scratch: 4.4x BLEU improvement
#   Fine-tuned vs From-scratch: 5.8x BLEU improvement
#   Fine-tuned vs Zero-shot: 1.3x BLEU improvement
# ✅ Three-way comparison complete!

# %% [markdown]
# ## 🎓 Key Insights from Three-Way Comparison
#
# ### 1. The Power of Pretraining
#
# **Zero-shot CodeT5+ (Part B) vs From-scratch (Part A):**
# - Even without task-specific training, pretrained model has advantages
# - Large-scale pretraining >> 374 MBPP examples
# - Transfer learning provides a massive head start
# - Zero-shot model understands Python syntax and patterns
#
# ### 2. The Power of Fine-Tuning
#
# **Fine-tuned CodeT5+ (Part C) vs Zero-shot CodeT5+ (Part B):**
# - Task-specific adaptation improves performance significantly
# - Only 5 epochs needed for substantial gains
# - Model learns MBPP format and style
# - Fine-tuning bridges the gap between general knowledge and specific task
#
# ### 3. Combined Effect: Pretrain + Fine-tune
#
# **Fine-tuned CodeT5+ (Part C) vs From-scratch (Part A):**
# - Expected 50-75x BLEU improvement
# - Syntax validity: 0% → 90%+ improvement
# - This is the **industry-standard approach**
# - Production-ready results with minimal task-specific training
#
# ### 4. Why This Matters for Production
#
# **Production Lessons:**
# 1. **Never train from scratch** for code generation in production
# 2. **Always start with pretrained models** (CodeT5, CodeGen, StarCoder, GPT-4)
# 3. **Fine-tune for your task** with just a few epochs
# 4. **Measure what matters**: BLEU + syntax validity > token accuracy
#
# **The Complete Picture:**
# - Part A taught you **how transformers work** (architecture, attention, training)
# - Part B taught you **the value of pretraining** (transfer learning)
# - Part C taught you **how to adapt models** (fine-tuning pipeline)
# - Together: **The industry-standard workflow**
#
# ### 5. Metrics Tell the Story
#
# **Why token accuracy (89% in Part A) was misleading:**
# - Token accuracy measures next-token prediction during training (teacher forcing)
# - BLEU measures actual generated sequence quality (autoregressive generation)
# - Syntax validity checks if code is parseable Python
# - High token accuracy ≠ good code generation
# - BLEU + syntax validity = true code quality metrics
#
# **Autoregressive error compounding:**
# - Part A: 89% accuracy → 0.89^50 ≈ 0% for 50-token sequences
# - Part C: Higher accuracy + better representations → much better sequences
# - This is why pretrained models + fine-tuning matter

# %% [markdown]
# ## 📊 Final Summary: What You Learned
#
# Congratulations! You've completed all three parts of Assignment 3!
#
# ### Part A (From Scratch) - Assignment3_PartA_Transformer.ipynb
# ✅ Built encoder-decoder transformer from scratch
# ✅ Understood self-attention, cross-attention, positional encoding
# ✅ Learned about teacher forcing vs autoregressive generation
# ✅ Discovered why small models struggle: BLEU 0.77, 0% syntax validity
#
# ### Part B (Pretrained Models) - Assignment3_PartB_Pretrained_Models.ipynb
# ✅ Loaded pretrained CodeT5+ model (220M parameters, large-scale pretraining)
# ✅ Tested zero-shot code generation (no task-specific training)
# ✅ Compared with Part A to see value of pretraining
# ✅ Understood transfer learning for code generation
#
# ### Part C (Fine-tuning) - THIS NOTEBOOK
# ✅ Fine-tuned CodeT5+ on MBPP (5 epochs, 5e-5 learning rate)
# ✅ Learned fine-tuning configuration (lower LR, fewer epochs)
# ✅ Compared three approaches: From-scratch → Zero-shot → Fine-tuned
# ✅ Understood the complete production pipeline
#
# ### Key Takeaways
#
# **1. Architecture Knowledge (Part A)**
# - How encoder-decoder transformers work internally
# - Self-attention, cross-attention, positional encoding
# - Why architecture alone isn't enough
#
# **2. Transfer Learning (Part B)**
# - Pretraining on large-scale code datasets provides strong foundation
# - Zero-shot capabilities from general code knowledge
# - Better than from-scratch even without task-specific training
#
# **3. Task Adaptation (Part C)**
# - Fine-tuning adapts pretrained models to specific tasks
# - Only 5 epochs needed (vs 20+ from scratch)
# - Lower learning rate preserves pretrained knowledge
# - Production-ready results: High BLEU, 90%+ syntax validity
#
# **4. Production Workflow**
# ```
# Step 1: Choose pretrained model (CodeT5, CodeGen, StarCoder, etc.)
# Step 2: Prepare task-specific dataset (MBPP or your own data)
# Step 3: Fine-tune with low LR (5e-5), few epochs (3-5)
# Step 4: Evaluate with BLEU + syntax validity (not just token accuracy)
# Step 5: Deploy and iterate
# ```
#
# **5. Metrics Matter**
# - Token accuracy can be misleading (89% looked good but was poor)
# - BLEU measures semantic similarity to reference code
# - Syntax validity checks if code is parseable
# - Both metrics together give true quality picture

# %% [markdown]
# ## 📝 Assignment 3 Complete!
#
# You've completed all three parts:
# - ✅ Part A: Built transformers from scratch → understood architecture
# - ✅ Part B: Explored pretrained models → saw transfer learning value
# - ✅ Part C: Fine-tuned for production → learned industry workflow
#
# ### Key Takeaways
#
# **Production Workflow:** Choose pretrained model → Prepare data → Fine-tune (low LR, few epochs) → Evaluate (BLEU + syntax) → Deploy
#
# **Metrics Matter:** Token accuracy (89%) ≠ code quality. BLEU + syntax validity reveal true performance.
#
# **Three-Part Progression:** Architecture knowledge (Part A) + Transfer learning (Part B) + Task adaptation (Part C) = Production-ready system
#
# ### For Your Report
#
# Include: (1) Three-way comparison table, (2) Training curves, (3) Example outputs, (4) Metrics analysis
#
# ### Optional Experiments
#
# - Experiment with more training data or different code datasets
# - Experiment with more epochs or different learning rates
# - Try other models (codet5-base, codegen, starcoder)
# - Add code execution validation
#
# 🎉 **Congratulations!**

# %%
NOTEBOOK_END_TIME = datetime.now()
elapsed = NOTEBOOK_END_TIME - NOTEBOOK_START_TIME
total_mins, total_secs = divmod(int(elapsed.total_seconds()), 60)
print(f"✅ Notebook complete")
print(f"Total time:  {total_mins}m {total_secs}s")
print(f"Current time: {NOTEBOOK_END_TIME.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ Notebook complete
# Total time:  130m 27s
# Current time: 2026-08-06 01:46:13
